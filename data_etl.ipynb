# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
csv_file1 = "Resources/cfb20.csv"
cfb_data1 = pd.read_csv(csv_file1)
cfb_data1.head()
# Out:
#                         Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0  Air Force (Mountain West)      6    3     3        73        373
# 1                Akron (MAC)      6    1     5       121        360
# 2              Alabama (SEC)     11   11     0         5        764
# 3       App State (Sun Belt)     12    9     3        26        845
# 4           Arizona (Pac-12)      5    0     5        86        373
#
#    Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 0       2336            6.26       19               389.3  ...
# 1       1687            4.69       12               281.2  ...
# 2       5983            7.83       68               543.9  ...
# 3       5424            6.42       49               452.0  ...
# 4       1847            4.95       10               369.4  ...
#
#    Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                32:30             58                  3
# 1                                30:35             98                  4
# 2                                30:45             12                 10
# 3                                32:18             57                  3
# 4                                28:01            126                  1
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      5               8             5
# 1                      2               6             3
# 2                     11              21             7
# 3                     15              18             6
# 4                      2               3             5
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       3               8                0
# 1                       6               9               -3
# 2                       4              11               10
# 3                      11              17                1
# 4                       7              12               -9
#
#    Avg.Turnover.Margin.per.Game
# 0                          0.00
# 1                         -0.50
# 2                          0.91
# 3                          0.08
# 4                         -1.80
#
# [5 rows x 152 columns]

# %%
cfb_data1.insert(0, 'Year', '2020')

# %%
cfb_data1.insert(0, 'Unique_ID', range(0, 0 + len(cfb_data1)))

# %%
#cfb_data1 = cfb_data1.set_index('Unique_ID')

# %%
cfb_data1['Conference'] = (np.where(cfb_data1['Team'].str.contains(''),
                  cfb_data1['Team'].str.split('(').str[1],
                  cfb_data1['Team']))
cfb_data1.head()
# Out:
#    Unique_ID  Year                       Team  Games  Win  Loss  Off.Rank  \
# 0          0  2020  Air Force (Mountain West)      6    3     3        73
# 1          1  2020                Akron (MAC)      6    1     5       121
# 2          2  2020              Alabama (SEC)     11   11     0         5
# 3          3  2020       App State (Sun Belt)     12    9     3        26
# 4          4  2020           Arizona (Pac-12)      5    0     5        86
#
#    Off.Plays  Off.Yards  Off.Yards.Play  ...  Turnover.Rank  \
# 0        373       2336            6.26  ...             58
# 1        360       1687            4.69  ...             98
# 2        764       5983            7.83  ...             12
# 3        845       5424            6.42  ...             57
# 4        373       1847            4.95  ...            126
#
#    Fumbles.Recovered  Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                  3                      5               8             5
# 1                  4                      2               6             3
# 2                 10                     11              21             7
# 3                  3                     15              18             6
# 4                  1                      2               3             5
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       3               8                0
# 1                       6               9               -3
# 2                       4              11               10
# 3                      11              17                1
# 4                       7              12               -9
#
#    Avg.Turnover.Margin.per.Game      Conference
# 0                          0.00  Mountain West)
# 1                         -0.50            MAC)
# 2                          0.91            SEC)
# 3                          0.08       Sun Belt)
# 4                         -1.80         Pac-12)
#
# [5 rows x 155 columns]

# %%
cfb_data1['Team'] = cfb_data1['Team'].str.split('(').str[0]
cfb_data1['Conference'] = cfb_data1['Conference'].str.split(')').str[0]
cfb_data1.head()
# Out:
#    Unique_ID  Year        Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0          0  2020  Air Force       6    3     3        73        373
# 1          1  2020      Akron       6    1     5       121        360
# 2          2  2020    Alabama      11   11     0         5        764
# 3          3  2020  App State      12    9     3        26        845
# 4          4  2020    Arizona       5    0     5        86        373
#
#    Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0       2336            6.26  ...             58                  3
# 1       1687            4.69  ...             98                  4
# 2       5983            7.83  ...             12                 10
# 3       5424            6.42  ...             57                  3
# 4       1847            4.95  ...            126                  1
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      5               8             5
# 1                      2               6             3
# 2                     11              21             7
# 3                     15              18             6
# 4                      2               3             5
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       3               8                0
# 1                       6               9               -3
# 2                       4              11               10
# 3                      11              17                1
# 4                       7              12               -9
#
#    Avg.Turnover.Margin.per.Game     Conference
# 0                          0.00  Mountain West
# 1                         -0.50            MAC
# 2                          0.91            SEC
# 3                          0.08       Sun Belt
# 4                         -1.80         Pac-12
#
# [5 rows x 155 columns]

# %%
cfb_data1.head()
# Out:
#    Unique_ID  Year        Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0          0  2020  Air Force       6    3     3        73        373
# 1          1  2020      Akron       6    1     5       121        360
# 2          2  2020    Alabama      11   11     0         5        764
# 3          3  2020  App State      12    9     3        26        845
# 4          4  2020    Arizona       5    0     5        86        373
#
#    Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0       2336            6.26  ...             58                  3
# 1       1687            4.69  ...             98                  4
# 2       5983            7.83  ...             12                 10
# 3       5424            6.42  ...             57                  3
# 4       1847            4.95  ...            126                  1
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      5               8             5
# 1                      2               6             3
# 2                     11              21             7
# 3                     15              18             6
# 4                      2               3             5
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       3               8                0
# 1                       6               9               -3
# 2                       4              11               10
# 3                      11              17                1
# 4                       7              12               -9
#
#    Avg.Turnover.Margin.per.Game     Conference
# 0                          0.00  Mountain West
# 1                         -0.50            MAC
# 2                          0.91            SEC
# 3                          0.08       Sun Belt
# 4                         -1.80         Pac-12
#
# [5 rows x 155 columns]

# %%
csv_file2 = "Resources/cfb19.csv"
cfb_data2 = pd.read_csv(csv_file2)
cfb_data2.head()
# Out:
#                          Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0   Air Force (Mountain West)     13   11     2        51        881
# 1                 Akron (MAC)     12    0    12       130        725
# 2               Alabama (SEC)     13   11     2         6        842
# 3  Appalachian St. (Sun Belt)     14   13     1        39        969
# 4            Arizona (Pac-12)     12    4     8        30        873
#
#    Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 0       5483            6.22       55               421.8  ...
# 1       2918            4.02       14               243.2  ...
# 2       6640            7.89       76               510.8  ...
# 3       6064            6.26       65               433.1  ...
# 4       5281            6.05       42               440.1  ...
#
#    Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                34:28             78                  9
# 1                                26:29            128                  6
# 2                                29:59              3                 11
# 3                                31:19              7                 10
# 4                                27:24             89                  4
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      7              16            12
# 1                      5              11            12
# 2                     17              28             4
# 3                     14              24             3
# 4                     11              15             6
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       6              18               -2
# 1                      14              26              -15
# 2                       6              10               18
# 3                       6               9               15
# 4                      12              18               -3
#
#    Avg.Turnover.Margin.per.Game
# 0                         -0.15
# 1                         -1.25
# 2                          1.38
# 3                          1.07
# 4                         -0.25
#
# [5 rows x 152 columns]

# %%
cfb_data2.insert(0, 'Year', '2019')

# %%
cfb_data2.insert(0, 'Unique_ID', range(0, 0 + len(cfb_data2)))

# %%
#cfb_data2 = cfb_data2.set_index('Unique_ID')

# %%
cfb_data2['Conference'] = (np.where(cfb_data2['Team'].str.contains(''),
                  cfb_data2['Team'].str.split('(').str[1],
                  cfb_data2['Team']))
cfb_data2.head()
# Out:
#    Unique_ID  Year                        Team  Games  Win  Loss  Off.Rank  \
# 0          0  2019   Air Force (Mountain West)     13   11     2        51
# 1          1  2019                 Akron (MAC)     12    0    12       130
# 2          2  2019               Alabama (SEC)     13   11     2         6
# 3          3  2019  Appalachian St. (Sun Belt)     14   13     1        39
# 4          4  2019            Arizona (Pac-12)     12    4     8        30
#
#    Off.Plays  Off.Yards  Off.Yards.Play  ...  Turnover.Rank  \
# 0        881       5483            6.22  ...             78
# 1        725       2918            4.02  ...            128
# 2        842       6640            7.89  ...              3
# 3        969       6064            6.26  ...              7
# 4        873       5281            6.05  ...             89
#
#    Fumbles.Recovered  Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                  9                      7              16            12
# 1                  6                      5              11            12
# 2                 11                     17              28             4
# 3                 10                     14              24             3
# 4                  4                     11              15             6
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       6              18               -2
# 1                      14              26              -15
# 2                       6              10               18
# 3                       6               9               15
# 4                      12              18               -3
#
#    Avg.Turnover.Margin.per.Game      Conference
# 0                         -0.15  Mountain West)
# 1                         -1.25            MAC)
# 2                          1.38            SEC)
# 3                          1.07       Sun Belt)
# 4                         -0.25         Pac-12)
#
# [5 rows x 155 columns]

# %%
cfb_data2['Team'] = cfb_data2['Team'].str.split('(').str[0]
cfb_data2['Conference'] = cfb_data2['Conference'].str.split(')').str[0]

# %%
cfb_data2.head()
# Out:
#    Unique_ID  Year              Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0          0  2019        Air Force      13   11     2        51        881
# 1          1  2019            Akron      12    0    12       130        725
# 2          2  2019          Alabama      13   11     2         6        842
# 3          3  2019  Appalachian St.      14   13     1        39        969
# 4          4  2019          Arizona      12    4     8        30        873
#
#    Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0       5483            6.22  ...             78                  9
# 1       2918            4.02  ...            128                  6
# 2       6640            7.89  ...              3                 11
# 3       6064            6.26  ...              7                 10
# 4       5281            6.05  ...             89                  4
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      7              16            12
# 1                      5              11            12
# 2                     17              28             4
# 3                     14              24             3
# 4                     11              15             6
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       6              18               -2
# 1                      14              26              -15
# 2                       6              10               18
# 3                       6               9               15
# 4                      12              18               -3
#
#    Avg.Turnover.Margin.per.Game     Conference
# 0                         -0.15  Mountain West
# 1                         -1.25            MAC
# 2                          1.38            SEC
# 3                          1.07       Sun Belt
# 4                         -0.25         Pac-12
#
# [5 rows x 155 columns]

# %%
csv_file3 = "Resources/cfb18.csv"
cfb_data3 = pd.read_csv(csv_file3)
cfb_data3
# Out:
#                            Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0               Air Force (MWC)     12    5     7        52        882
# 1                   Akron (MAC)     12    4     8       126        764
# 2                 Alabama (SEC)     15   14     1         6       1009
# 3    Appalachian St. (Sun Belt)     13   11     2        37        859
# 4              Arizona (Pac-12)     12    5     7        24        881
# ..                          ...    ...  ...   ...       ...        ...
# 124      West Virginia (Big 12)     12    8     4         8        870
# 125         Western Ky. (C-USA)     12    3     9       101        870
# 126         Western Mich. (MAC)     13    7     6        35        962
# 127         Wisconsin (Big Ten)     13    8     5        36        875
# 128               Wyoming (MWC)     12    6     6       118        771
#
#      Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 0         4978            5.64       43               414.8  ...
# 1         3533            4.62       21               294.4  ...
# 2         7830            7.76       85               522.0  ...
# 3         5603            6.52       58               431.0  ...
# 4         5492            6.23       43               457.7  ...
# ..         ...             ...      ...                 ...  ...
# 124       6147            7.07       60               512.3  ...
# 125       4364            5.02       30               363.7  ...
# 126       5679            5.90       52               436.8  ...
# 127       5604            6.40       51               431.1  ...
# 128       3969            5.15       27               330.8  ...
#
#      Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                  34:22             77                  7
# 1                                  28:09            103                 11
# 2                                  30:19             34                  7
# 3                                  30:34             30                  6
# 4                                  28:15             90                  8
# ..                                   ...            ...                ...
# 124                                28:50             23                  9
# 125                                29:23             52                  6
# 126                                33:36             63                 11
# 127                                32:04             63                 11
# 128                                29:56             40                  5
#
#      Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                        7              14            10
# 1                       10              21            12
# 2                       14              21             7
# 3                       17              23             5
# 4                        7              15             9
# ..                     ...             ...           ...
# 124                     15              24             7
# 125                     12              18             6
# 126                      9              20            10
# 127                     14              25            10
# 128                     10              15             7
#
#      Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                         5              15               -1
# 1                        14              26               -5
# 2                         8              15                6
# 3                        12              17                6
# 4                        10              19               -4
# ..                      ...             ...              ...
# 124                      10              17                7
# 125                      10              16                2
# 126                       9              19                1
# 127                      14              24                1
# 128                       4              11                4
#
#      Avg.Turnover.Margin.per.Game
# 0                           -0.08
# 1                           -0.42
# 2                            0.40
# 3                            0.46
# 4                           -0.33
# ..                            ...
# 124                          0.58
# 125                          0.17
# 126                          0.08
# 127                          0.08
# 128                          0.33
#
# [129 rows x 152 columns]

# %%
cfb_data3.insert(0, 'Year', '2018')

# %%
cfb_data3.insert(0, 'Unique_ID', range(0, 0 + len(cfb_data3)))

# %%
#cfb_data3 = cfb_data3.set_index('Unique_ID')

# %%
cfb_data3['Conference'] = (np.where(cfb_data3['Team'].str.contains(''),
                  cfb_data3['Team'].str.split('(').str[1],
                  cfb_data3['Team']))

# %%
cfb_data3['Team'] = cfb_data3['Team'].str.split('(').str[0]
cfb_data3['Conference'] = cfb_data3['Conference'].str.split(')').str[0]

# %%
cfb_data3.head()
# Out:
#    Unique_ID  Year              Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0          0  2018        Air Force      12    5     7        52        882
# 1          1  2018            Akron      12    4     8       126        764
# 2          2  2018          Alabama      15   14     1         6       1009
# 3          3  2018  Appalachian St.      13   11     2        37        859
# 4          4  2018          Arizona      12    5     7        24        881
#
#    Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0       4978            5.64  ...             77                  7
# 1       3533            4.62  ...            103                 11
# 2       7830            7.76  ...             34                  7
# 3       5603            6.52  ...             30                  6
# 4       5492            6.23  ...             90                  8
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      7              14            10
# 1                     10              21            12
# 2                     14              21             7
# 3                     17              23             5
# 4                      7              15             9
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                       5              15               -1
# 1                      14              26               -5
# 2                       8              15                6
# 3                      12              17                6
# 4                      10              19               -4
#
#    Avg.Turnover.Margin.per.Game  Conference
# 0                         -0.08         MWC
# 1                         -0.42         MAC
# 2                          0.40         SEC
# 3                          0.46    Sun Belt
# 4                         -0.33      Pac-12
#
# [5 rows x 155 columns]

# %%
partial_append_df = cfb_data2.append(cfb_data3)

# %%
final_df = cfb_data1.append(partial_append_df)

# %%
final_df
# Out:
#      Unique_ID  Year            Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0            0  2020      Air Force       6    3     3        73        373
# 1            1  2020          Akron       6    1     5       121        360
# 2            2  2020        Alabama      11   11     0         5        764
# 3            3  2020      App State      12    9     3        26        845
# 4            4  2020        Arizona       5    0     5        86        373
# ..         ...   ...             ...    ...  ...   ...       ...        ...
# 124        124  2018  West Virginia      12    8     4         8        870
# 125        125  2018    Western Ky.      12    3     9       101        870
# 126        126  2018  Western Mich.      13    7     6        35        962
# 127        127  2018      Wisconsin      13    8     5        36        875
# 128        128  2018        Wyoming      12    6     6       118        771
#
#      Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0         2336            6.26  ...             58                  3
# 1         1687            4.69  ...             98                  4
# 2         5983            7.83  ...             12                 10
# 3         5424            6.42  ...             57                  3
# 4         1847            4.95  ...            126                  1
# ..         ...             ...  ...            ...                ...
# 124       6147            7.07  ...             23                  9
# 125       4364            5.02  ...             52                  6
# 126       5679            5.90  ...             63                 11
# 127       5604            6.40  ...             63                 11
# 128       3969            5.15  ...             40                  5
#
#      Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                        5               8             5
# 1                        2               6             3
# 2                       11              21             7
# 3                       15              18             6
# 4                        2               3             5
# ..                     ...             ...           ...
# 124                     15              24             7
# 125                     12              18             6
# 126                      9              20            10
# 127                     14              25            10
# 128                     10              15             7
#
#      Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                         3               8                0
# 1                         6               9               -3
# 2                         4              11               10
# 3                        11              17                1
# 4                         7              12               -9
# ..                      ...             ...              ...
# 124                      10              17                7
# 125                      10              16                2
# 126                       9              19                1
# 127                      14              24                1
# 128                       4              11                4
#
#      Avg.Turnover.Margin.per.Game     Conference
# 0                            0.00  Mountain West
# 1                           -0.50            MAC
# 2                            0.91            SEC
# 3                            0.08       Sun Belt
# 4                           -1.80         Pac-12
# ..                            ...            ...
# 124                          0.58         Big 12
# 125                          0.17          C-USA
# 126                          0.08            MAC
# 127                          0.08        Big Ten
# 128                          0.33            MWC
#
# [386 rows x 155 columns]

# %%
#final_df.insert(0, 'Unique_ID', range(0, 0 + len(final_df)))

# %%
#final_df = final_df.set_index('Unique_ID')

# %%
final_df['Team'] = final_df['Team'].str.strip()
final_df['Conference'] = final_df['Conference'].str.strip()

# %%
final_df
# Out:
#      Unique_ID  Year           Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0            0  2020      Air Force      6    3     3        73        373
# 1            1  2020          Akron      6    1     5       121        360
# 2            2  2020        Alabama     11   11     0         5        764
# 3            3  2020      App State     12    9     3        26        845
# 4            4  2020        Arizona      5    0     5        86        373
# ..         ...   ...            ...    ...  ...   ...       ...        ...
# 124        124  2018  West Virginia     12    8     4         8        870
# 125        125  2018    Western Ky.     12    3     9       101        870
# 126        126  2018  Western Mich.     13    7     6        35        962
# 127        127  2018      Wisconsin     13    8     5        36        875
# 128        128  2018        Wyoming     12    6     6       118        771
#
#      Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0         2336            6.26  ...             58                  3
# 1         1687            4.69  ...             98                  4
# 2         5983            7.83  ...             12                 10
# 3         5424            6.42  ...             57                  3
# 4         1847            4.95  ...            126                  1
# ..         ...             ...  ...            ...                ...
# 124       6147            7.07  ...             23                  9
# 125       4364            5.02  ...             52                  6
# 126       5679            5.90  ...             63                 11
# 127       5604            6.40  ...             63                 11
# 128       3969            5.15  ...             40                  5
#
#      Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                        5               8             5
# 1                        2               6             3
# 2                       11              21             7
# 3                       15              18             6
# 4                        2               3             5
# ..                     ...             ...           ...
# 124                     15              24             7
# 125                     12              18             6
# 126                      9              20            10
# 127                     14              25            10
# 128                     10              15             7
#
#      Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                         3               8                0
# 1                         6               9               -3
# 2                         4              11               10
# 3                        11              17                1
# 4                         7              12               -9
# ..                      ...             ...              ...
# 124                      10              17                7
# 125                      10              16                2
# 126                       9              19                1
# 127                      14              24                1
# 128                       4              11                4
#
#      Avg.Turnover.Margin.per.Game     Conference
# 0                            0.00  Mountain West
# 1                           -0.50            MAC
# 2                            0.91            SEC
# 3                            0.08       Sun Belt
# 4                           -1.80         Pac-12
# ..                            ...            ...
# 124                          0.58         Big 12
# 125                          0.17          C-USA
# 126                          0.08            MAC
# 127                          0.08        Big Ten
# 128                          0.33            MWC
#
# [386 rows x 155 columns]

# %%
final_df.loc[final_df['Team'] == 'Alabama']
# Out:
#    Unique_ID  Year     Team  Games  Win  Loss  Off.Rank  Off.Plays  Off.Yards  \
# 2          2  2020  Alabama     11   11     0         5        764       5983
# 2          2  2019  Alabama     13   11     2         6        842       6640
# 2          2  2018  Alabama     15   14     1         6       1009       7830
#
#    Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 2            7.83  ...             12                 10
# 2            7.89  ...              3                 11
# 2            7.76  ...             34                  7
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 2                     11              21             7
# 2                     17              28             4
# 2                     14              21             7
#
#    Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 2                       4              11               10
# 2                       6              10               18
# 2                       8              15                6
#
#    Avg.Turnover.Margin.per.Game  Conference
# 2                          0.91         SEC
# 2                          1.38         SEC
# 2                          0.40         SEC
#
# [3 rows x 155 columns]

# %%
final_df.columns = final_df.columns.str.replace('.', '_')
# Out:
# <ipython-input-222-aa8c013ec172>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   final_df.columns = final_df.columns.str.replace('.', '_')

# %%
final_df
# Out:
#      Unique_ID  Year           Team  Games  Win  Loss  Off_Rank  Off_Plays  \
# 0            0  2020      Air Force      6    3     3        73        373
# 1            1  2020          Akron      6    1     5       121        360
# 2            2  2020        Alabama     11   11     0         5        764
# 3            3  2020      App State     12    9     3        26        845
# 4            4  2020        Arizona      5    0     5        86        373
# ..         ...   ...            ...    ...  ...   ...       ...        ...
# 124        124  2018  West Virginia     12    8     4         8        870
# 125        125  2018    Western Ky.     12    3     9       101        870
# 126        126  2018  Western Mich.     13    7     6        35        962
# 127        127  2018      Wisconsin     13    8     5        36        875
# 128        128  2018        Wyoming     12    6     6       118        771
#
#      Off_Yards  Off_Yards_Play  ...  Turnover_Rank  Fumbles_Recovered  \
# 0         2336            6.26  ...             58                  3
# 1         1687            4.69  ...             98                  4
# 2         5983            7.83  ...             12                 10
# 3         5424            6.42  ...             57                  3
# 4         1847            4.95  ...            126                  1
# ..         ...             ...  ...            ...                ...
# 124       6147            7.07  ...             23                  9
# 125       4364            5.02  ...             52                  6
# 126       5679            5.90  ...             63                 11
# 127       5604            6.40  ...             63                 11
# 128       3969            5.15  ...             40                  5
#
#      Opponents_Intercepted  Turnovers_Gain  Fumbles_Lost  \
# 0                        5               8             5
# 1                        2               6             3
# 2                       11              21             7
# 3                       15              18             6
# 4                        2               3             5
# ..                     ...             ...           ...
# 124                     15              24             7
# 125                     12              18             6
# 126                      9              20            10
# 127                     14              25            10
# 128                     10              15             7
#
#      Interceptions_Thrown_y  Turnovers_Lost  Turnover_Margin  \
# 0                         3               8                0
# 1                         6               9               -3
# 2                         4              11               10
# 3                        11              17                1
# 4                         7              12               -9
# ..                      ...             ...              ...
# 124                      10              17                7
# 125                      10              16                2
# 126                       9              19                1
# 127                      14              24                1
# 128                       4              11                4
#
#      Avg_Turnover_Margin_per_Game     Conference
# 0                            0.00  Mountain West
# 1                           -0.50            MAC
# 2                            0.91            SEC
# 3                            0.08       Sun Belt
# 4                           -1.80         Pac-12
# ..                            ...            ...
# 124                          0.58         Big 12
# 125                          0.17          C-USA
# 126                          0.08            MAC
# 127                          0.08        Big Ten
# 128                          0.33            MWC
#
# [386 rows x 155 columns]

# %%
columns = final_df.columns.values.tolist()
columns
# Out:
# ['Unique_ID',
#  'Year',
#  'Team',
#  'Games',
#  'Win',
#  'Loss',
#  'Off_Rank',
#  'Off_Plays',
#  'Off_Yards',
#  'Off_Yards_Play',
#  'Off_TDs',
#  'Off_Yards_per_Game',
#  'Def_Rank',
#  'Def_Plays',
#  'Yards_Allowed',
#  'Yards_Play_Allowed',
#  'Off_TDs_Allowed',
#  'Total_TDs_Allowed',
#  'Yards_Per_Game_Allowed',
#  'First_Down_Rank',
#  'First_Down_Runs',
#  'First_Down_Passes',
#  'First_Down_Penalties',
#  'First_Downs',
#  'First_Down_Def_Rank',
#  'Opp_First_Down_Runs',
#  'Opp_First_Down_Passes',
#  'Opp_First_Down_Penalties',
#  'Opp_First_Downs',
#  'X4th_Down_Rank',
#  'X4th_Attempts',
#  'X4th_Conversions',
#  'X4th_Percent',
#  'X4rd_Down_Def_Rank',
#  'Opp_4th_Conversion',
#  'Opp_4th_Attempt',
#  'Opponent_4th_Percent',
#  'Kickoff_Return_Rank',
#  'Kickoffs_Returned',
#  'Kickoff_Return_Yards',
#  'Kickoff_Return_Touchdowns',
#  'Avg_Yard_per_Kickoff_Return',
#  '___40',
#  'Kickoff_Return_Def_Rank',
#  'Opp_Kickoff_Returns',
#  'Kickoff_Touchbacks',
#  'Opponent_Kickoff_Return_Yards',
#  'Opp_Kickoff_Return_Touchdowns_Allowed',
#  'Avg_Yards_per_Kickoff_Return_Allowed',
#  'Passing_Off_Rank',
#  'Pass_Attempts',
#  'Pass_Completions',
#  'Interceptions_Thrown_x',
#  'Pass_Yards',
#  'Pass_Yards_Attempt',
#  'Yards_Completion',
#  'Pass_Touchdowns',
#  'Pass_Yards_Per_Game',
#  'Pass_Def_Rank',
#  'Opp_Completions_Allowed',
#  'Opp_Pass_Attempts',
#  'Opp_Pass_Yds_Allowed',
#  'Opp_Pass_TDs_Allowed',
#  'Yards_Attempt_Allowed',
#  'Yards_Completion_Allowed',
#  'Pass_Yards_Per_Game_Allowed',
#  'Penalty_Rank',
#  'Penalties',
#  'Penalty_Yards',
#  'Penalty_Yards_Per_Game',
#  'Punt_Return_Rank',
#  'Punt_Returns',
#  'Net_Punt_Return_Yards',
#  'Punt_Return_Touchdowns',
#  'Avg_Yards_Per_Punt_Return',
#  'Punt_Return_Def_Rank',
#  'Opp_Punt_Returns',
#  'Opp_Net_Punt_Return_Yards',
#  'Opp_Punt_Return_Touchdowns_Allowed',
#  'Avg_Yards_Allowed_per_Punt_Return',
#  'Redzone_Off_Rank',
#  'Redzone_Attempts',
#  'Redzone_Rush_TD',
#  'Redzone_Pass_TD',
#  'Redzone_Field_Goals_Made',
#  'Redzone_Scores',
#  'Redzone_Points',
#  'Redzone_Def_Rank',
#  'Opp_Redzone_Attempts',
#  'Opp_Redzone_Rush_TD_Allowed',
#  'Opp_Redzone_Pass_Touchdowns_Allowed',
#  'Opp_Redzone_Field_Goals_Made',
#  'Opp_Redzone_Scores',
#  'Redzone_Points_Allowed',
#  'Rushing_Off_Rank',
#  'Rush_Attempts',
#  'Rush_Yds',
#  'Yards_Rush',
#  'Rushing_TD',
#  'Rushing_Yards_per_Game',
#  'Rushing_Def_Rank',
#  'Opp_Rush_Attempts',
#  'Opp_Rush_Yards_Alloweed',
#  'Yds_Rush_Allowed',
#  'Opp_Rush_Touchdowns_Allowed',
#  'Rush_Yards_Per_Game_Allowed',
#  'Sack_Rank',
#  'Sacks',
#  'Sack_Yards',
#  'Average_Sacks_per_Game',
#  'Scoring_Def_Rank',
#  'Touchdowns_Allowed',
#  'Opponent_Extra_Points',
#  'X2_Point_Conversions_Allowed',
#  'Opp_Deflected_Extra_Points',
#  'Opp_Feild_Goals_Made',
#  'Opp_Safety',
#  'Points_Allowed',
#  'Avg_Points_per_Game_Allowed',
#  'Scoring_Off_Rank',
#  'Touchdowns',
#  'PAT',
#  'X2_Point_Conversions',
#  'Defensive_Points',
#  'Feild_Goals',
#  'Safety',
#  'Total_Points',
#  'Points_Per_Game',
#  'Tackle_for_Loss_Rank',
#  'Solo_Tackle_For_Loss',
#  'Assist_Tackle_For_Loss',
#  'Tackle_for_Loss_Yards',
#  'Total_Tackle_For_Loss',
#  'Tackle_For_Loss_Per_Game',
#  'X3rd_Down_Rank',
#  'X3rd_Attempts',
#  'X3rd_Conversions',
#  'X3rd_Percent',
#  'X3rd_Down_Def_Rank',
#  'Opp_3rd_Conversion',
#  'Opp_3rd_Attempt',
#  'Opponent_3rd_Percent',
#  'Time_of_Possession_Rank',
#  'Time_of_Possession',
#  'Average_Time_of_Possession_per_Game',
#  'Turnover_Rank',
#  'Fumbles_Recovered',
#  'Opponents_Intercepted',
#  'Turnovers_Gain',
#  'Fumbles_Lost',
#  'Interceptions_Thrown_y',
#  'Turnovers_Lost',
#  'Turnover_Margin',
#  'Avg_Turnover_Margin_per_Game',
#  'Conference']

# %%
win_loss = final_df[["Unique_ID", "Team", "Games", "Win", "Loss"]]
win_loss.set_index("Unique_ID", inplace=True)
win_loss
# Out:
#                     Team  Games  Win  Loss
# Unique_ID
# 0              Air Force      6    3     3
# 1                  Akron      6    1     5
# 2                Alabama     11   11     0
# 3              App State     12    9     3
# 4                Arizona      5    0     5
# ...                  ...    ...  ...   ...
# 124        West Virginia     12    8     4
# 125          Western Ky.     12    3     9
# 126        Western Mich.     13    7     6
# 127            Wisconsin     13    8     5
# 128              Wyoming     12    6     6
#
# [386 rows x 4 columns]

# %%
offense = final_df[['Team','Unique_ID',
 'Off_Rank',
 'Off_Plays',
 'Off_Yards',
 'Off_Yards_Play',
 'Off_TDs',
 'Off_Yards_per_Game',
 'Scoring_Off_Rank',
 'Points_Per_Game']]
offense.set_index("Unique_ID", inplace=True)
offense
# Out:
#                     Team  Off_Rank  Off_Plays  Off_Yards  Off_Yards_Play  \
# Unique_ID
# 0              Air Force        73        373       2336            6.26
# 1                  Akron       121        360       1687            4.69
# 2                Alabama         5        764       5983            7.83
# 3              App State        26        845       5424            6.42
# 4                Arizona        86        373       1847            4.95
# ...                  ...       ...        ...        ...             ...
# 124        West Virginia         8        870       6147            7.07
# 125          Western Ky.       101        870       4364            5.02
# 126        Western Mich.        35        962       5679            5.90
# 127            Wisconsin        36        875       5604            6.40
# 128              Wyoming       118        771       3969            5.15
#
#            Off_TDs  Off_Yards_per_Game
# Unique_ID
# 0               19               389.3
# 1               12               281.2
# 2               68               543.9
# 3               49               452.0
# 4               10               369.4
# ...            ...                 ...
# 124             60               512.3
# 125             30               363.7
# 126             52               436.8
# 127             51               431.1
# 128             27               330.8
#
# [386 rows x 7 columns]

# %%
defense = final_df[['Team','Unique_ID',
 'Def_Rank',
 'Def_Plays',
 'Yards_Allowed',
 'Yards_Play_Allowed',
 'Off_TDs_Allowed',
 'Total_TDs_Allowed',
 'Yards_Per_Game_Allowed',
 'Touchdowns_Allowed',
 'Points_Allowed']]
defense.set_index("Unique_ID", inplace=True)
defense
# Out:
#                     Team  Def_Rank  Def_Plays  Yards_Allowed  \
# Unique_ID
# 0              Air Force         8        360           1820
# 1                  Akron       110        365           2759
# 2                Alabama        33        767           3863
# 3              App State        18        798           3946
# 4                Arizona       116        351           2365
# ...                  ...       ...        ...            ...
# 124        West Virginia        74        839           4876
# 125          Western Ky.        82        862           5059
# 126        Western Mich.        57        813           5026
# 127            Wisconsin        29        814           4474
# 128              Wyoming        19        818           3914
#
#            Yards_Play_Allowed  Off_TDs_Allowed  Total_TDs_Allowed  \
# Unique_ID
# 0                        5.06               11                 12
# 1                        7.56               31                 34
# 2                        5.04               25                 25
# 3                        4.94               27                 30
# 4                        6.74               25                 26
# ...                       ...              ...                ...
# 124                      5.81               39                 41
# 125                      5.87               36                 37
# 126                      6.18               57                 60
# 127                      5.50               31                 33
# 128                      4.78               32                 33
#
#            Yards_Per_Game_Allowed
# Unique_ID
# 0                           303.3
# 1                           459.8
# 2                           351.2
# 3                           328.8
# 4                           473.0
# ...                           ...
# 124                         406.3
# 125                         421.6
# 126                         386.6
# 127                         344.2
# 128                         326.2
#
# [386 rows x 8 columns]

# %%
offense_firstdowns = final_df[['Team','Unique_ID',
 'First_Down_Rank',
 'First_Down_Runs',
 'First_Down_Passes',
 'First_Down_Penalties',
 'First_Downs']]
offense_firstdowns.set_index("Unique_ID", inplace=True)
offense_firstdowns
# Out:
#                     Team  First_Down_Rank  First_Down_Runs  First_Down_Passes  \
# Unique_ID
# 0              Air Force               14               52                 46
# 1                  Akron               24               68                 49
# 2                Alabama               92               76                119
# 3              App State              101              105                 95
# 4                Arizona               16               55                 43
# ...                  ...              ...              ...                ...
# 124        West Virginia               73              112                131
# 125          Western Ky.               72              112                127
# 126        Western Mich.               58              112                123
# 127            Wisconsin               19               98                108
# 128              Wyoming               16               96                111
#
#            First_Down_Penalties  First_Downs
# Unique_ID
# 0                             8          106
# 1                             7          124
# 2                            21          216
# 3                            23          223
# 4                            10          108
# ...                         ...          ...
# 124                          19          262
# 125                          22          261
# 126                          20          255
# 127                          24          230
# 128                          16          223
#
# [386 rows x 6 columns]

# %%
defense_firstdowns = final_df[['Team','Unique_ID',
 'Opp_First_Down_Runs',
 'Opp_First_Down_Passes',
 'Opp_First_Down_Penalties',
 'Opp_First_Downs']]
defense_firstdowns.set_index("Unique_ID", inplace=True)
defense_firstdowns
# Out:
#                     Team  Opp_First_Down_Runs  Opp_First_Down_Passes  \
# Unique_ID
# 0              Air Force                   52                     46
# 1                  Akron                   68                     49
# 2                Alabama                   76                    119
# 3              App State                  105                     95
# 4                Arizona                   55                     43
# ...                  ...                  ...                    ...
# 124        West Virginia                  112                    131
# 125          Western Ky.                  112                    127
# 126        Western Mich.                  112                    123
# 127            Wisconsin                   98                    108
# 128              Wyoming                   96                    111
#
#            Opp_First_Down_Penalties  Opp_First_Downs
# Unique_ID
# 0                                 8              106
# 1                                 7              124
# 2                                21              216
# 3                                23              223
# 4                                10              108
# ...                             ...              ...
# 124                              19              262
# 125                              22              261
# 126                              20              255
# 127                              24              230
# 128                              16              223
#
# [386 rows x 5 columns]

# %%
offense_fourthdowns = final_df[['Team','Unique_ID',
 'X4th_Down_Rank',
 'X4th_Attempts',
 'X4th_Conversions',
 'X4th_Percent']]
offense_fourthdowns.set_index("Unique_ID", inplace=True)
offense_fourthdowns
# Out:
#                     Team  X4th_Down_Rank  X4th_Attempts  X4th_Conversions  \
# Unique_ID
# 0              Air Force              14              8                11
# 1                  Akron              98              4                 9
# 2                Alabama             102              3                 7
# 3              App State              61             11                20
# 4                Arizona             122              3                12
# ...                  ...             ...            ...               ...
# 124        West Virginia              49              9                16
# 125          Western Ky.             115              9                24
# 126        Western Mich.              40             20                34
# 127            Wisconsin             109              5                12
# 128              Wyoming             123              4                12
#
#            X4th_Percent
# Unique_ID
# 0                 0.727
# 1                 0.444
# 2                 0.429
# 3                 0.550
# 4                 0.250
# ...                 ...
# 124               0.563
# 125               0.375
# 126               0.588
# 127               0.417
# 128               0.333
#
# [386 rows x 5 columns]

# %%
defense_fourthdowns = final_df[['Team','Unique_ID',
 'Opp_4th_Conversion',
 'Opp_4th_Attempt',
 'Opponent_4th_Percent'
]]
defense_fourthdowns.set_index("Unique_ID", inplace=True)
defense_fourthdowns
# Out:
#                     Team  Opp_4th_Conversion  Opp_4th_Attempt  \
# Unique_ID
# 0              Air Force                   3               10
# 1                  Akron                   4                7
# 2                Alabama                  11               19
# 3              App State                  13               27
# 4                Arizona                   5                8
# ...                  ...                 ...              ...
# 124        West Virginia                  12               19
# 125          Western Ky.                  12               22
# 126        Western Mich.                   8               16
# 127            Wisconsin                   7               13
# 128              Wyoming                  11               16
#
#            Opponent_4th_Percent
# Unique_ID
# 0                         0.300
# 1                         0.571
# 2                         0.579
# 3                         0.481
# 4                         0.625
# ...                         ...
# 124                       0.632
# 125                       0.545
# 126                       0.500
# 127                       0.538
# 128                       0.688
#
# [386 rows x 4 columns]

# %%
offense_kickoffs = final_df[['Team','Unique_ID',
 'Kickoffs_Returned',
 'Kickoff_Return_Yards',
 'Kickoff_Return_Touchdowns',
 'Avg_Yard_per_Kickoff_Return']]
offense_kickoffs.set_index("Unique_ID", inplace=True)
offense_kickoffs
# Out:
#                     Team  Kickoffs_Returned  Kickoff_Return_Yards  \
# Unique_ID
# 0              Air Force                 14                     9
# 1                  Akron                 16                     6
# 2                Alabama                 33                    17
# 3              App State                 42                    17
# 4                Arizona                  2                    17
# ...                  ...                ...                   ...
# 124        West Virginia                 44                    25
# 125          Western Ky.                 35                    13
# 126        Western Mich.                 57                     6
# 127            Wisconsin                 13                    54
# 128              Wyoming                 22                    30
#
#            Kickoff_Return_Touchdowns  Avg_Yard_per_Kickoff_Return
# Unique_ID
# 0                                324                            1
# 1                                340                            0
# 2                                610                            0
# 3                                728                            1
# 4                                110                            1
# ...                              ...                          ...
# 124                              850                            0
# 125                              758                            0
# 126                             1087                            1
# 127                              263                            0
# 128                              456                            1
#
# [386 rows x 5 columns]

# %%
defense_kickoffs = final_df[['Team','Unique_ID',
 'Opp_Kickoff_Returns',
 'Kickoff_Touchbacks',
 'Opponent_Kickoff_Return_Yards',
 'Opp_Kickoff_Return_Touchdowns_Allowed',
 'Avg_Yards_per_Kickoff_Return_Allowed']]
defense_kickoffs.set_index("Unique_ID", inplace=True)
defense_kickoffs
# Out:
#                     Team  Opp_Kickoff_Returns  Kickoff_Touchbacks  \
# Unique_ID
# 0              Air Force                   14                   9
# 1                  Akron                   16                   6
# 2                Alabama                   33                  17
# 3              App State                   42                  17
# 4                Arizona                    2                  17
# ...                  ...                  ...                 ...
# 124        West Virginia                   44                  25
# 125          Western Ky.                   35                  13
# 126        Western Mich.                   57                   6
# 127            Wisconsin                   13                  54
# 128              Wyoming                   22                  30
#
#            Opponent_Kickoff_Return_Yards  \
# Unique_ID
# 0                                    324
# 1                                    340
# 2                                    610
# 3                                    728
# 4                                    110
# ...                                  ...
# 124                                  850
# 125                                  758
# 126                                 1087
# 127                                  263
# 128                                  456
#
#            Opp_Kickoff_Return_Touchdowns_Allowed  \
# Unique_ID
# 0                                              1
# 1                                              0
# 2                                              0
# 3                                              1
# 4                                              1
# ...                                          ...
# 124                                            0
# 125                                            0
# 126                                            1
# 127                                            0
# 128                                            1
#
#            Avg_Yards_per_Kickoff_Return_Allowed
# Unique_ID
# 0                                         23.14
# 1                                         21.25
# 2                                         18.48
# 3                                         17.33
# 4                                         55.00
# ...                                         ...
# 124                                       19.32
# 125                                       21.66
# 126                                       19.07
# 127                                       20.23
# 128                                       20.73
#
# [386 rows x 6 columns]

# %%
offense_passing = final_df[['Team','Unique_ID',
 'Passing_Off_Rank',
 'Pass_Attempts',
 'Pass_Completions',
 'Interceptions_Thrown_x',
 'Pass_Yards',
 'Pass_Yards_Attempt',
 'Yards_Completion',
 'Pass_Touchdowns',
 'Pass_Yards_Per_Game']]
offense_passing.set_index("Unique_ID", inplace=True)
offense_passing
# Out:
#                     Team  Passing_Off_Rank  Pass_Attempts  Pass_Completions  \
# Unique_ID
# 0              Air Force               126             61                34
# 1                  Akron               119            148                83
# 2                Alabama                 5            350               263
# 3              App State               105            300               190
# 4                Arizona                77            189               114
# ...                  ...               ...            ...               ...
# 124        West Virginia                 4            445               291
# 125          Western Ky.                69            431               254
# 126        Western Mich.                62            396               243
# 127            Wisconsin               118            304               179
# 128              Wyoming               124            276               135
#
#            Interceptions_Thrown_x  Pass_Yards  Pass_Yards_Attempt  \
# Unique_ID
# 0                               3         502                8.23
# 1                               6         838                5.66
# 2                               4        3895               11.13
# 3                              11        2245                7.48
# 4                               7        1065                5.63
# ...                           ...         ...                 ...
# 124                            10        4216                9.47
# 125                            10        2722                6.32
# 126                             9        3086                7.79
# 127                            14        2050                6.74
# 128                             4        1576                5.71
#
#            Yards_Completion  Pass_Touchdowns  Pass_Yards_Per_Game
# Unique_ID
# 0                     14.76                3                 83.7
# 1                     10.10                4                139.7
# 2                     14.81               33                354.1
# 3                     11.82               21                187.1
# 4                      9.34                6                213.0
# ...                     ...              ...                  ...
# 124                   14.49               38                351.3
# 125                   10.72               15                226.8
# 126                   12.70               20                237.4
# 127                   11.45               19                157.7
# 128                   11.67                8                131.3
#
# [386 rows x 10 columns]

# %%
defense_passing = final_df[['Team','Unique_ID',
 'Opp_Completions_Allowed',
 'Opp_Pass_Attempts',
 'Opp_Pass_Yds_Allowed',
 'Opp_Pass_TDs_Allowed',
 'Yards_Attempt_Allowed',
 'Yards_Completion_Allowed',
 'Pass_Yards_Per_Game_Allowed']]
defense_passing.set_index("Unique_ID", inplace=True)
defense_passing
# Out:
#                     Team  Opp_Completions_Allowed  Opp_Pass_Attempts  \
# Unique_ID
# 0              Air Force                       88                143
# 1                  Akron                       85                127
# 2                Alabama                      227                393
# 3              App State                      168                350
# 4                Arizona                       80                122
# ...                  ...                      ...                ...
# 124        West Virginia                      247                389
# 125          Western Ky.                      228                406
# 126        Western Mich.                      205                328
# 127            Wisconsin                      209                360
# 128              Wyoming                      241                394
#
#            Opp_Pass_Yds_Allowed  Opp_Pass_TDs_Allowed  Yards_Attempt_Allowed  \
# Unique_ID
# 0                          1001                     7                   7.00
# 1                          1270                    12                  10.00
# 2                          2679                    14                   6.82
# 3                          2135                    13                   6.10
# 4                          1012                     6                   8.30
# ...                         ...                   ...                    ...
# 124                        3104                    22                   7.98
# 125                        2985                    17                   7.35
# 126                        2870                    30                   8.75
# 127                        2458                    14                   6.83
# 128                        2360                    15                   5.99
#
#            Yards_Completion_Allowed  Pass_Yards_Per_Game_Allowed
# Unique_ID
# 0                             11.38                        166.8
# 1                             14.94                        211.7
# 2                             11.80                        243.5
# 3                             12.71                        177.9
# 4                             12.65                        202.4
# ...                             ...                          ...
# 124                           12.57                        258.7
# 125                           13.09                        248.8
# 126                           14.00                        220.8
# 127                           11.76                        189.1
# 128                            9.79                        196.7
#
# [386 rows x 8 columns]

# %%
penalties = final_df[['Team','Unique_ID',
 'Penalty_Rank',
 'Penalties',
 'Penalty_Yards',
 'Penalty_Yards_Per_Game']]
penalties.set_index("Unique_ID", inplace=True)
penalties
# Out:
#                     Team  Penalty_Rank  Penalties  Penalty_Yards  \
# Unique_ID
# 0              Air Force            19         27            245
# 1                  Akron             2         24            190
# 2                Alabama            46         66            522
# 3              App State           107         88            811
# 4                Arizona            89         34            294
# ...                  ...           ...        ...            ...
# 124        West Virginia           106         85            800
# 125          Western Ky.            77         79            683
# 126        Western Mich.            59         77            678
# 127            Wisconsin            56         74            657
# 128              Wyoming            51         72            596
#
#            Penalty_Yards_Per_Game
# Unique_ID
# 0                           40.83
# 1                           31.67
# 2                           47.45
# 3                           67.58
# 4                           58.80
# ...                           ...
# 124                         66.67
# 125                         56.92
# 126                         52.15
# 127                         50.54
# 128                         49.67
#
# [386 rows x 5 columns]

# %%
offense_punts = final_df[['Team','Unique_ID',
 'Punt_Return_Rank',
 'Punt_Returns',
 'Net_Punt_Return_Yards',
 'Punt_Return_Touchdowns',
 'Avg_Yards_Per_Punt_Return',
]]
offense_punts.set_index("Unique_ID", inplace=True)
offense_punts
# Out:
#                     Team  Punt_Return_Rank  Punt_Returns  \
# Unique_ID
# 0              Air Force                26             4
# 1                  Akron                67            20
# 2                Alabama                32             4
# 3              App State                14            18
# 4                Arizona                92             6
# ...                  ...               ...           ...
# 124        West Virginia                56             9
# 125          Western Ky.                99             7
# 126        Western Mich.                58            13
# 127            Wisconsin               109            17
# 128              Wyoming                44            21
#
#            Net_Punt_Return_Yards  Punt_Return_Touchdowns  \
# Unique_ID
# 0                             15                       0
# 1                            144                       0
# 2                             19                       0
# 3                             39                       0
# 4                             61                       0
# ...                          ...                     ...
# 124                           69                       0
# 125                           72                       0
# 126                          102                       1
# 127                          191                       1
# 128                          136                       0
#
#            Avg_Yards_Per_Punt_Return
# Unique_ID
# 0                               3.75
# 1                               7.20
# 2                               4.75
# 3                               2.17
# 4                              10.17
# ...                              ...
# 124                             7.67
# 125                            10.29
# 126                             7.85
# 127                            11.24
# 128                             6.48
#
# [386 rows x 6 columns]

# %%
defense_punts = final_df[['Team','Unique_ID',
 'Punt_Return_Def_Rank',
 'Opp_Punt_Returns',
 'Opp_Net_Punt_Return_Yards',
 'Opp_Punt_Return_Touchdowns_Allowed',
 'Avg_Yards_Allowed_per_Punt_Return'
]]
defense_punts.set_index("Unique_ID", inplace=True)
defense_punts
# Out:
#                     Team  Punt_Return_Def_Rank  Opp_Punt_Returns  \
# Unique_ID
# 0              Air Force                    26                 4
# 1                  Akron                    67                20
# 2                Alabama                    32                 4
# 3              App State                    14                18
# 4                Arizona                    92                 6
# ...                  ...                   ...               ...
# 124        West Virginia                    56                 9
# 125          Western Ky.                    99                 7
# 126        Western Mich.                    58                13
# 127            Wisconsin                   109                17
# 128              Wyoming                    44                21
#
#            Opp_Net_Punt_Return_Yards  Opp_Punt_Return_Touchdowns_Allowed  \
# Unique_ID
# 0                                 15                                   0
# 1                                144                                   0
# 2                                 19                                   0
# 3                                 39                                   0
# 4                                 61                                   0
# ...                              ...                                 ...
# 124                               69                                   0
# 125                               72                                   0
# 126                              102                                   1
# 127                              191                                   1
# 128                              136                                   0
#
#            Avg_Yards_Allowed_per_Punt_Return
# Unique_ID
# 0                                       3.75
# 1                                       7.20
# 2                                       4.75
# 3                                       2.17
# 4                                      10.17
# ...                                      ...
# 124                                     7.67
# 125                                    10.29
# 126                                     7.85
# 127                                    11.24
# 128                                     6.48
#
# [386 rows x 6 columns]

# %%
offense_redzone = final_df[['Team','Unique_ID',
 'Redzone_Off_Rank',
 'Redzone_Attempts',
 'Redzone_Rush_TD',
 'Redzone_Pass_TD',
 'Redzone_Field_Goals_Made',
 'Redzone_Scores',
 'Redzone_Points']]
offense_redzone.set_index("Unique_ID", inplace=True)
offense_redzone
# Out:
#                     Team  Redzone_Off_Rank  Redzone_Attempts  Redzone_Rush_TD  \
# Unique_ID
# 0              Air Force               117                24               13
# 1                  Akron                41                14                5
# 2                Alabama                11                60               30
# 3              App State               106                52               17
# 4                Arizona               119                13                3
# ...                  ...               ...               ...              ...
# 124        West Virginia                89                53               17
# 125          Western Ky.               119                42               14
# 126        Western Mich.                83                55               27
# 127            Wisconsin                41                53               21
# 128              Wyoming                87                27                7
#
#            Redzone_Pass_TD  Redzone_Field_Goals_Made  Redzone_Scores  \
# Unique_ID
# 0                        1                         3              17
# 1                        4                         3              12
# 2                       16                         9              55
# 3                       13                         9              39
# 4                        2                         4               9
# ...                    ...                       ...             ...
# 124                     18                         8              43
# 125                     11                         7              32
# 126                      9                         9              45
# 127                     16                         9              46
# 128                      5                        10              22
#
#            Redzone_Points
# Unique_ID
# 0                   0.708
# 1                   0.857
# 2                   0.917
# 3                   0.750
# 4                   0.692
# ...                   ...
# 124                 0.811
# 125                 0.762
# 126                 0.818
# 127                 0.868
# 128                 0.815
#
# [386 rows x 8 columns]

# %%
defense_redzone = final_df[['Team','Unique_ID',
 'Redzone_Def_Rank',
 'Opp_Redzone_Attempts',
 'Opp_Redzone_Rush_TD_Allowed',
 'Opp_Redzone_Pass_Touchdowns_Allowed',
 'Opp_Redzone_Field_Goals_Made',
 'Opp_Redzone_Scores',
 'Redzone_Points_Allowed'
]]
defense_redzone.set_index("Unique_ID", inplace=True)
defense_redzone
# Out:
#                     Team  Redzone_Def_Rank  Opp_Redzone_Attempts  \
# Unique_ID
# 0              Air Force                 5                    13
# 1                  Akron                33                    27
# 2                Alabama                28                    30
# 3              App State                24                    37
# 4                Arizona               104                    28
# ...                  ...               ...                   ...
# 124        West Virginia                93                    45
# 125          Western Ky.                51                    49
# 126        Western Mich.               117                    55
# 127            Wisconsin                77                    44
# 128              Wyoming                91                    36
#
#            Opp_Redzone_Rush_TD_Allowed  Opp_Redzone_Pass_Touchdowns_Allowed  \
# Unique_ID
# 0                                    4                                    3
# 1                                   15                                    5
# 2                                   10                                    5
# 3                                   12                                    7
# 4                                   16                                    3
# ...                                ...                                  ...
# 124                                 14                                   14
# 125                                 13                                   10
# 126                                 21                                   22
# 127                                 14                                    9
# 128                                 15                                    9
#
#            Opp_Redzone_Field_Goals_Made  Opp_Redzone_Scores  \
# Unique_ID
# 0                                     2                   9
# 1                                     1                  21
# 2                                     8                  23
# 3                                     9                  28
# 4                                     6                  25
# ...                                 ...                 ...
# 124                                  11                  39
# 125                                  17                  40
# 126                                   7                  50
# 127                                  14                  37
# 128                                   7                  31
#
#            Redzone_Points_Allowed
# Unique_ID
# 0                           0.692
# 1                           0.778
# 2                           0.767
# 3                           0.757
# 4                           0.893
# ...                           ...
# 124                         0.867
# 125                         0.816
# 126                         0.909
# 127                         0.841
# 128                         0.861
#
# [386 rows x 8 columns]

# %%
offense_rushing = final_df[['Team','Unique_ID',
 'Rushing_Off_Rank',
 'Rush_Attempts',
 'Rush_Yds',
 'Yards_Rush',
 'Rushing_TD',
 'Rushing_Yards_per_Game']]
offense_rushing.set_index("Unique_ID", inplace=True)
offense_rushing
# Out:
#                     Team  Rushing_Off_Rank  Rush_Attempts  Rush_Yds  \
# Unique_ID
# 0              Air Force                 1            312      1834
# 1                  Akron                86            212       849
# 2                Alabama                44            414      2088
# 3              App State                 7            545      3179
# 4                Arizona                73            184       782
# ...                  ...               ...            ...       ...
# 124        West Virginia                75            425      1931
# 125          Western Ky.               103            439      1642
# 126        Western Mich.                38            566      2593
# 127            Wisconsin                 6            571      3554
# 128              Wyoming                39            495      2393
#
#            Yards_Rush  Rushing_TD  Rushing_Yards_per_Game
# Unique_ID
# 0                5.88          16                   305.7
# 1                4.00           8                   141.5
# 2                5.04          35                   189.8
# 3                5.83          28                   264.9
# 4                4.25           4                   156.4
# ...               ...         ...                     ...
# 124              4.54          22                   160.9
# 125              3.74          15                   136.8
# 126              4.58          32                   199.5
# 127              6.22          32                   273.4
# 128              4.83          19                   199.4
#
# [386 rows x 7 columns]

# %%
defense_rushing = final_df[['Team','Unique_ID',
 'Rushing_Def_Rank',
 'Opp_Rush_Attempts',
 'Opp_Rush_Yards_Alloweed',
 'Yds_Rush_Allowed',
 'Opp_Rush_Touchdowns_Allowed',
 'Rush_Yards_Per_Game_Allowed']]
defense_rushing.set_index("Unique_ID", inplace=True)
defense_rushing
# Out:
#                     Team  Rushing_Def_Rank  Opp_Rush_Attempts  \
# Unique_ID
# 0              Air Force                33                217
# 1                  Akron               120                238
# 2                Alabama                12                374
# 3              App State                49                448
# 4                Arizona               125                229
# ...                  ...               ...                ...
# 124        West Virginia                48                450
# 125          Western Ky.                77                456
# 126        Western Mich.                68                485
# 127            Wisconsin                54                454
# 128              Wyoming                25                424
#
#            Opp_Rush_Yards_Alloweed  Yds_Rush_Allowed  \
# Unique_ID
# 0                              819              3.77
# 1                             1489              6.26
# 2                             1184              3.17
# 3                             1811              4.04
# 4                             1353              5.91
# ...                            ...               ...
# 124                           1772              3.94
# 125                           2074              4.55
# 126                           2156              4.45
# 127                           2016              4.44
# 128                           1554              3.67
#
#            Opp_Rush_Touchdowns_Allowed  Rush_Yards_Per_Game_Allowed
# Unique_ID
# 0                                    4                        136.5
# 1                                   19                        248.2
# 2                                   11                        107.6
# 3                                   14                        150.9
# 4                                   19                        270.6
# ...                                ...                          ...
# 124                                 17                        147.7
# 125                                 19                        172.8
# 126                                 27                        165.8
# 127                                 17                        155.1
# 128                                 17                        129.5
#
# [386 rows x 7 columns]

# %%
sacks = final_df[['Team','Unique_ID',
 'Sack_Rank',
 'Sacks',
 'Sack_Yards',
 'Average_Sacks_per_Game']]
sacks.set_index("Unique_ID", inplace=True)
sacks
# Out:
#                     Team  Sack_Rank  Sacks  Sack_Yards  Average_Sacks_per_Game
# Unique_ID
# 0              Air Force          3      2          19                    0.33
# 1                  Akron        125     26         162                    4.33
# 2                Alabama         25     16         101                    1.45
# 3              App State         40     21         131                    1.75
# 4                Arizona        120     18         118                    3.60
# ...                  ...        ...    ...         ...                     ...
# 124        West Virginia         82     29         204                    2.42
# 125          Western Ky.         97     32         204                    2.67
# 126        Western Mich.         27     20         103                    1.54
# 127            Wisconsin         43     24         151                    1.85
# 128              Wyoming         53     24         204                    2.00
#
# [386 rows x 5 columns]

# %%
turnovers = final_df[['Team','Unique_ID',
 'Turnover_Rank',
 'Fumbles_Recovered',
 'Opponents_Intercepted',
 'Turnovers_Gain',
 'Fumbles_Lost',
 'Interceptions_Thrown_y',
 'Turnovers_Lost',
 'Turnover_Margin',
 'Avg_Turnover_Margin_per_Game']]
turnovers.set_index("Unique_ID", inplace=True)
turnovers
# Out:
#                     Team  Turnover_Rank  Fumbles_Recovered  \
# Unique_ID
# 0              Air Force             58                  3
# 1                  Akron             98                  4
# 2                Alabama             12                 10
# 3              App State             57                  3
# 4                Arizona            126                  1
# ...                  ...            ...                ...
# 124        West Virginia             23                  9
# 125          Western Ky.             52                  6
# 126        Western Mich.             63                 11
# 127            Wisconsin             63                 11
# 128              Wyoming             40                  5
#
#            Opponents_Intercepted  Turnovers_Gain  Fumbles_Lost  \
# Unique_ID
# 0                              5               8             5
# 1                              2               6             3
# 2                             11              21             7
# 3                             15              18             6
# 4                              2               3             5
# ...                          ...             ...           ...
# 124                           15              24             7
# 125                           12              18             6
# 126                            9              20            10
# 127                           14              25            10
# 128                           10              15             7
#
#            Interceptions_Thrown_y  Turnovers_Lost  Turnover_Margin  \
# Unique_ID
# 0                               3               8                0
# 1                               6               9               -3
# 2                               4              11               10
# 3                              11              17                1
# 4                               7              12               -9
# ...                           ...             ...              ...
# 124                            10              17                7
# 125                            10              16                2
# 126                             9              19                1
# 127                            14              24                1
# 128                             4              11                4
#
#            Avg_Turnover_Margin_per_Game
# Unique_ID
# 0                                  0.00
# 1                                 -0.50
# 2                                  0.91
# 3                                  0.08
# 4                                 -1.80
# ...                                 ...
# 124                                0.58
# 125                                0.17
# 126                                0.08
# 127                                0.08
# 128                                0.33
#
# [386 rows x 10 columns]

# %%
rds_connection_string = "postgres:Speaker34j!@localhost:5432/college_football"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# []

# %%
win_loss.to_sql(name='win_loss', con=engine, if_exists='append', index=False)

# %%
offense.to_sql(name='offense', con=engine, if_exists='append', index=False)

# %%
defense.to_sql(name='defense', con=engine, if_exists='append', index=False)

# %%
offense_firstdowns.to_sql(name='offense_firstdowns', con=engine, if_exists='append', index=False)

# %%
defense_firstdowns.to_sql(name='defense_firstdowns', con=engine, if_exists='append', index=False)

# %%
offense_fourthdowns.to_sql(name='offense_fourthdowns', con=engine, if_exists='append', index=False)

# %%
defense_fourthdowns.to_sql(name='defense_fourthdowns', con=engine, if_exists='append', index=False)

# %%
offense_kickoffs.to_sql(name='offense_kickoffs', con=engine, if_exists='append', index=False)

# %%
defense_kickoffs.to_sql(name='defense_kickoffs', con=engine, if_exists='append', index=False)

# %%
offense_passing.to_sql(name='offense_passing', con=engine, if_exists='append', index=False)

# %%
defense_passing.to_sql(name='defense_passing', con=engine, if_exists='append', index=False)

# %%
penalties.to_sql(name='penalties', con=engine, if_exists='append', index=False)

# %%
offense_punts.to_sql(name='offense_punts', con=engine, if_exists='append', index=False)

# %%
defense_punts.to_sql(name='defense_punts', con=engine, if_exists='append', index=False)

# %%
offense_redzone.to_sql(name='offense_redzone', con=engine, if_exists='append', index=False)

# %%
defense_redzone.to_sql(name='defense_redzone', con=engine, if_exists='append', index=False)

# %%
offense_rushing.to_sql(name='offense_rushing', con=engine, if_exists='append', index=False)

# %%
defense_rushing.to_sql(name='defense_rushing', con=engine, if_exists='append', index=False)

# %%
sacks.to_sql(name='sacks', con=engine, if_exists='append', index=False)

# %%
turnovers.to_sql(name='turnovers', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['offense',
#  'defense',
#  'offense_firstdowns',
#  'defense_firstdowns',
#  'offense_fourthdowns',
#  'offense_kickoffs',
#  'defense_kickoffs',
#  'offense_passing',
#  'defense_passing',
#  'penalties',
#  'offense_punts',
#  'defense_punts',
#  'offense_redzone',
#  'defense_redzone',
#  'offense_rushing',
#  'defense_rushing',
#  'sacks',
#  'turnovers',
#  'defense_fourthdowns']

# %%
pd.read_sql_query('select * from turnovers where ', con=engine)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# SyntaxError: syntax error at end of input
# LINE 1: select * from turnovers where
#                                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-300-b306d8cd5cf1> in <module>
# ----> 1 pd.read_sql_query('select * from turnovers where ', con=engine)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     386     """
#     387     pandas_sql = pandasSQL_builder(con)
# --> 388     return pandas_sql.read_query(
#     389         sql,
#     390         index_col=index_col,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1306         args = _convert_params(sql, params)
#    1307
# -> 1308         result = self.execute(*args)
#    1309         columns = result.keys()
#    1310
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1174     def execute(self, *args, **kwargs):
#    1175         """Simple passthrough to SQLAlchemy connectable"""
# -> 1176         return self.connectable.execution_options().execute(*args, **kwargs)
#    1177
#    1178     def read_table(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2235
#    2236         connection = self._contextual_connect(close_with_result=True)
# -> 2237         return connection.execute(statement, *multiparams, **params)
#    2238
#    2239     def scalar(self, statement, *multiparams, **params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1001         """
#    1002         if isinstance(object_, util.string_types[0]):
# -> 1003             return self._execute_text(object_, multiparams, params)
#    1004         try:
#    1005             meth = object_._execute_on_connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1170         dialect = self.dialect
#    1171         parameters = _distill_params(multiparams, params)
# -> 1172         ret = self._execute_context(
#    1173             dialect,
#    1174             dialect.execution_ctx_cls._init_statement,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1274                             break
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#    1278                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.SyntaxError) syntax error at end of input
# LINE 1: select * from turnovers where
#                                       ^
#
# [SQL: select * from turnovers where ]
# (Background on this error at: http://sqlalche.me/e/13/f405)
