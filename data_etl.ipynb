# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
csv_file1 = "Resources/cfb20.csv"
cfb_data1 = pd.read_csv(csv_file1)
cfb_data1.head()
# Out:
#                         Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0  Air Force (Mountain West)      6    3     3        73        373
# 1                Akron (MAC)      6    1     5       121        360
# 2              Alabama (SEC)     11   11     0         5        764
# 3       App State (Sun Belt)     12    9     3        26        845
# 4           Arizona (Pac-12)      5    0     5        86        373
#
#    Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 0       2336            6.26       19               389.3  ...
# 1       1687            4.69       12               281.2  ...
# 2       5983            7.83       68               543.9  ...
# 3       5424            6.42       49               452.0  ...
# 4       1847            4.95       10               369.4  ...
#
#    Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                32:30             58                  3
# ...

# %%
cfb_data1.insert(0, 'Year', '2020')

# %%
cfb_data1.insert(0, 'Unique_ID', range(0, 0 + len(cfb_data1)))

# %%
#cfb_data1 = cfb_data1.set_index('Unique_ID')

# %%
cfb_data1['Conference'] = (np.where(cfb_data1['Team'].str.contains(''),
                  cfb_data1['Team'].str.split('(').str[1],
                  cfb_data1['Team']))
cfb_data1.head()
# Out:
#    Unique_ID  Year                       Team  Games  Win  Loss  Off.Rank  \
# 0          0  2020  Air Force (Mountain West)      6    3     3        73
# 1          1  2020                Akron (MAC)      6    1     5       121
# 2          2  2020              Alabama (SEC)     11   11     0         5
# 3          3  2020       App State (Sun Belt)     12    9     3        26
# 4          4  2020           Arizona (Pac-12)      5    0     5        86
#
#    Off.Plays  Off.Yards  Off.Yards.Play  ...  Turnover.Rank  \
# 0        373       2336            6.26  ...             58
# 1        360       1687            4.69  ...             98
# 2        764       5983            7.83  ...             12
# 3        845       5424            6.42  ...             57
# 4        373       1847            4.95  ...            126
#
#    Fumbles.Recovered  Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                  3                      5               8             5
# ...

# %%
cfb_data1['Team'] = cfb_data1['Team'].str.split('(').str[0]
cfb_data1['Conference'] = cfb_data1['Conference'].str.split(')').str[0]
cfb_data1.head()
# Out:
#    Unique_ID  Year        Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0          0  2020  Air Force       6    3     3        73        373
# 1          1  2020      Akron       6    1     5       121        360
# 2          2  2020    Alabama      11   11     0         5        764
# 3          3  2020  App State      12    9     3        26        845
# 4          4  2020    Arizona       5    0     5        86        373
#
#    Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0       2336            6.26  ...             58                  3
# 1       1687            4.69  ...             98                  4
# 2       5983            7.83  ...             12                 10
# 3       5424            6.42  ...             57                  3
# 4       1847            4.95  ...            126                  1
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      5               8             5
# ...

# %%
cfb_data1.head()
# Out:
#    Unique_ID  Year        Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0          0  2020  Air Force       6    3     3        73        373
# 1          1  2020      Akron       6    1     5       121        360
# 2          2  2020    Alabama      11   11     0         5        764
# 3          3  2020  App State      12    9     3        26        845
# 4          4  2020    Arizona       5    0     5        86        373
#
#    Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0       2336            6.26  ...             58                  3
# 1       1687            4.69  ...             98                  4
# 2       5983            7.83  ...             12                 10
# 3       5424            6.42  ...             57                  3
# 4       1847            4.95  ...            126                  1
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                      5               8             5
# ...

# %%
csv_file2 = "Resources/cfb19.csv"
cfb_data2 = pd.read_csv(csv_file2)
cfb_data2.head()
# Out:
#                          Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0   Air Force (Mountain West)     13   11     2        51        881
# 1                 Akron (MAC)     12    0    12       130        725
# 2               Alabama (SEC)     13   11     2         6        842
# 3  Appalachian St. (Sun Belt)     14   13     1        39        969
# 4            Arizona (Pac-12)     12    4     8        30        873
#
#    Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# 0       5483            6.22       55               421.8  ...
# 1       2918            4.02       14               243.2  ...
# 2       6640            7.89       76               510.8  ...
# 3       6064            6.26       65               433.1  ...
# 4       5281            6.05       42               440.1  ...
#
#    Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                34:28             78                  9
# ...

# %%
cfb_data2.insert(0, 'Year', '2019')

# %%
cfb_data2.insert(0, 'Unique_ID', range(0, 0 + len(cfb_data2)))

# %%
#cfb_data2 = cfb_data2.set_index('Unique_ID')

# %%
cfb_data2['Conference'] = (np.where(cfb_data2['Team'].str.contains(''),
                  cfb_data2['Team'].str.split('(').str[1],
                  cfb_data2['Team']))
cfb_data2.head()
# Out:
#    Unique_ID  Year                        Team  Games  Win  Loss  Off.Rank  \
# 0          0  2019   Air Force (Mountain West)     13   11     2        51
# 1          1  2019                 Akron (MAC)     12    0    12       130
# 2          2  2019               Alabama (SEC)     13   11     2         6
# 3          3  2019  Appalachian St. (Sun Belt)     14   13     1        39
# 4          4  2019            Arizona (Pac-12)     12    4     8        30
#
#    Off.Plays  Off.Yards  Off.Yards.Play  ...  Turnover.Rank  \
# 0        881       5483            6.22  ...             78
# 1        725       2918            4.02  ...            128
# 2        842       6640            7.89  ...              3
# 3        969       6064            6.26  ...              7
# 4        873       5281            6.05  ...             89
#
#    Fumbles.Recovered  Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                  9                      7              16            12
# ...

# %%
cfb_data2['Team'] = cfb_data2['Team'].str.split('(').str[0]
cfb_data2['Conference'] = cfb_data2['Conference'].str.split(')').str[0]

# %%
cfb_data2.head()
# Out:
#    Unique_ID  Year              Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0          0  2019        Air Force      13   11     2        51        881
# 1          1  2019            Akron      12    0    12       130        725
# 2          2  2019          Alabama      13   11     2         6        842
# 3          3  2019  Appalachian St.      14   13     1        39        969
# 4          4  2019          Arizona      12    4     8        30        873
#
#    Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0       5483            6.22  ...             78                  9
# 1       2918            4.02  ...            128                  6
# 2       6640            7.89  ...              3                 11
# 3       6064            6.26  ...              7                 10
# 4       5281            6.05  ...             89                  4
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# ...

# %%
csv_file3 = "Resources/cfb18.csv"
cfb_data3 = pd.read_csv(csv_file3)
cfb_data3
# Out:
#                            Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0               Air Force (MWC)     12    5     7        52        882
# 1                   Akron (MAC)     12    4     8       126        764
# 2                 Alabama (SEC)     15   14     1         6       1009
# 3    Appalachian St. (Sun Belt)     13   11     2        37        859
# 4              Arizona (Pac-12)     12    5     7        24        881
# ..                          ...    ...  ...   ...       ...        ...
# 124      West Virginia (Big 12)     12    8     4         8        870
# 125         Western Ky. (C-USA)     12    3     9       101        870
# 126         Western Mich. (MAC)     13    7     6        35        962
# 127         Wisconsin (Big Ten)     13    8     5        36        875
# 128               Wyoming (MWC)     12    6     6       118        771
#
#      Off.Yards  Off.Yards.Play  Off.TDs  Off.Yards.per.Game  ...  \
# ...

# %%
cfb_data3.insert(0, 'Year', '2018')

# %%
cfb_data3.insert(0, 'Unique_ID', range(0, 0 + len(cfb_data3)))

# %%
#cfb_data3 = cfb_data3.set_index('Unique_ID')

# %%
cfb_data3['Conference'] = (np.where(cfb_data3['Team'].str.contains(''),
                  cfb_data3['Team'].str.split('(').str[1],
                  cfb_data3['Team']))

# %%
cfb_data3['Team'] = cfb_data3['Team'].str.split('(').str[0]
cfb_data3['Conference'] = cfb_data3['Conference'].str.split(')').str[0]

# %%
cfb_data3.head()
# Out:
#    Unique_ID  Year              Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0          0  2018        Air Force      12    5     7        52        882
# 1          1  2018            Akron      12    4     8       126        764
# 2          2  2018          Alabama      15   14     1         6       1009
# 3          3  2018  Appalachian St.      13   11     2        37        859
# 4          4  2018          Arizona      12    5     7        24        881
#
#    Off.Yards  Off.Yards.Play  ...  Turnover.Rank  Fumbles.Recovered  \
# 0       4978            5.64  ...             77                  7
# 1       3533            4.62  ...            103                 11
# 2       7830            7.76  ...             34                  7
# 3       5603            6.52  ...             30                  6
# 4       5492            6.23  ...             90                  8
#
#    Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# ...

# %%
partial_append_df = cfb_data2.append(cfb_data3)

# %%
final_df = cfb_data1.append(partial_append_df)

# %%
final_df
# Out:
#      Unique_ID  Year            Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0            0  2020      Air Force       6    3     3        73        373
# 1            1  2020          Akron       6    1     5       121        360
# 2            2  2020        Alabama      11   11     0         5        764
# 3            3  2020      App State      12    9     3        26        845
# 4            4  2020        Arizona       5    0     5        86        373
# ..         ...   ...             ...    ...  ...   ...       ...        ...
# 124        124  2018  West Virginia      12    8     4         8        870
# 125        125  2018    Western Ky.      12    3     9       101        870
# 126        126  2018  Western Mich.      13    7     6        35        962
# 127        127  2018      Wisconsin      13    8     5        36        875
# 128        128  2018        Wyoming      12    6     6       118        771
#
# ...

# %%
#final_df.insert(0, 'Unique_ID', range(0, 0 + len(final_df)))

# %%
#final_df = final_df.set_index('Unique_ID')

# %%
final_df['Team'] = final_df['Team'].str.strip()
final_df['Conference'] = final_df['Conference'].str.strip()

# %%
final_df.head(50)
# Out:
#     Unique_ID  Year              Team  Games  Win  Loss  Off_Rank  Off_Plays  \
# 0           0  2020         Air Force      6    3     3        73        373
# 1           1  2020             Akron      6    1     5       121        360
# 2           2  2020           Alabama     11   11     0         5        764
# 3           3  2020         App State     12    9     3        26        845
# 4           4  2020           Arizona      5    0     5        86        373
# 5           5  2020       Arizona St.      4    2     2        20        252
# 6           6  2020          Arkansas     10    3     7        67        678
# 7           7  2020      Arkansas St.     11    4     7        13        849
# 8           8  2020   Army West Point     11    9     2       112        727
# 9           9  2020            Auburn     10    6     4        75        685
# 10         10  2020          Ball St.      7    6     1        24        547
# ...

# %%
final_df.loc[final_df['Team'] == 'Alabama']
# Out:
#    Unique_ID  Year     Team  Games  Win  Loss  Off_Rank  Off_Plays  Off_Yards  \
# 2          2  2020  Alabama     11   11     0         5        764       5983
# 2          2  2019  Alabama     13   11     2         6        842       6640
# 2          2  2018  Alabama     15   14     1         6       1009       7830
#
#    Off_Yards_Play  ...  Turnover_Rank  Fumbles_Recovered  \
# 2            7.83  ...             12                 10
# 2            7.89  ...              3                 11
# 2            7.76  ...             34                  7
#
#    Opponents_Intercepted  Turnovers_Gain  Fumbles_Lost  \
# 2                     11              21             7
# 2                     17              28             4
# 2                     14              21             7
#
#    Interceptions_Thrown_y  Turnovers_Lost  Turnover_Margin  \
# 2                       4              11               10
# 2                       6              10               18
# ...

# %%
final_df.columns = final_df.columns.str.replace('.', '_')
# Out:
# <ipython-input-222-aa8c013ec172>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   final_df.columns = final_df.columns.str.replace('.', '_')

# %%
final_df
# Out:
#      Unique_ID  Year           Team  Games  Win  Loss  Off_Rank  Off_Plays  \
# 0            0  2020      Air Force      6    3     3        73        373
# 1            1  2020          Akron      6    1     5       121        360
# 2            2  2020        Alabama     11   11     0         5        764
# 3            3  2020      App State     12    9     3        26        845
# 4            4  2020        Arizona      5    0     5        86        373
# ..         ...   ...            ...    ...  ...   ...       ...        ...
# 124        124  2018  West Virginia     12    8     4         8        870
# 125        125  2018    Western Ky.     12    3     9       101        870
# 126        126  2018  Western Mich.     13    7     6        35        962
# 127        127  2018      Wisconsin     13    8     5        36        875
# 128        128  2018        Wyoming     12    6     6       118        771
#
# ...

# %%
columns = final_df.columns.values.tolist()
columns
# Out:
# ['Unique_ID',
#  'Year',
#  'Team',
#  'Games',
#  'Win',
#  'Loss',
#  'Off_Rank',
#  'Off_Plays',
#  'Off_Yards',
#  'Off_Yards_Play',
#  'Off_TDs',
#  'Off_Yards_per_Game',
#  'Def_Rank',
#  'Def_Plays',
#  'Yards_Allowed',
#  'Yards_Play_Allowed',
#  'Off_TDs_Allowed',
#  'Total_TDs_Allowed',
#  'Yards_Per_Game_Allowed',
#  'First_Down_Rank',
#  'First_Down_Runs',
#  'First_Down_Passes',
#  'First_Down_Penalties',
#  'First_Downs',
#  'First_Down_Def_Rank',
#  'Opp_First_Down_Runs',
#  'Opp_First_Down_Passes',
#  'Opp_First_Down_Penalties',
#  'Opp_First_Downs',
#  'X4th_Down_Rank',
#  'X4th_Attempts',
#  'X4th_Conversions',
#  'X4th_Percent',
#  'X4rd_Down_Def_Rank',
#  'Opp_4th_Conversion',
#  'Opp_4th_Attempt',
#  'Opponent_4th_Percent',
#  'Kickoff_Return_Rank',
#  'Kickoffs_Returned',
#  'Kickoff_Return_Yards',
#  'Kickoff_Return_Touchdowns',
#  'Avg_Yard_per_Kickoff_Return',
#  '___40',
#  'Kickoff_Return_Def_Rank',
#  'Opp_Kickoff_Returns',
#  'Kickoff_Touchbacks',
# ...

# %%
win_loss = final_df[["Unique_ID", "Year", "Team", "Games", "Win", "Loss"]]
win_loss.set_index("Unique_ID", inplace=True)
win_loss
# Out:
#            Year           Team  Games  Win  Loss
# Unique_ID
# 0          2020      Air Force      6    3     3
# 1          2020          Akron      6    1     5
# 2          2020        Alabama     11   11     0
# 3          2020      App State     12    9     3
# 4          2020        Arizona      5    0     5
# ...         ...            ...    ...  ...   ...
# 124        2018  West Virginia     12    8     4
# 125        2018    Western Ky.     12    3     9
# 126        2018  Western Mich.     13    7     6
# 127        2018      Wisconsin     13    8     5
# 128        2018        Wyoming     12    6     6
#
# [386 rows x 5 columns]

# %%
offense = final_df[['Year','Team','Unique_ID',
 'Off_Rank',
 'Off_Plays',
 'Off_Yards',
 'Off_Yards_Play',
 'Off_TDs',
 'Off_Yards_per_Game',
 'Scoring_Off_Rank',
 'Points_Per_Game']]
offense.set_index("Unique_ID", inplace=True)
offense
# Out:
#            Year           Team  Off_Rank  Off_Plays  Off_Yards  \
# Unique_ID
# 0          2020      Air Force        73        373       2336
# 1          2020          Akron       121        360       1687
# 2          2020        Alabama         5        764       5983
# 3          2020      App State        26        845       5424
# 4          2020        Arizona        86        373       1847
# ...         ...            ...       ...        ...        ...
# 124        2018  West Virginia         8        870       6147
# 125        2018    Western Ky.       101        870       4364
# 126        2018  Western Mich.        35        962       5679
# 127        2018      Wisconsin        36        875       5604
# 128        2018        Wyoming       118        771       3969
#
#            Off_Yards_Play  Off_TDs  Off_Yards_per_Game  Scoring_Off_Rank  \
# Unique_ID
# 0                    6.26       19               389.3                92
# ...

# %%
defense = final_df[['Year','Team','Unique_ID',
 'Def_Rank',
 'Def_Plays',
 'Yards_Allowed',
 'Yards_Play_Allowed',
 'Off_TDs_Allowed',
 'Total_TDs_Allowed',
 'Yards_Per_Game_Allowed',
 'Touchdowns_Allowed',
 'Points_Allowed']]
defense.set_index("Unique_ID", inplace=True)
defense
# Out:
#            Year           Team  Def_Rank  Def_Plays  Yards_Allowed  \
# Unique_ID
# 0          2020      Air Force         8        360           1820
# 1          2020          Akron       110        365           2759
# 2          2020        Alabama        33        767           3863
# 3          2020      App State        18        798           3946
# 4          2020        Arizona       116        351           2365
# ...         ...            ...       ...        ...            ...
# 124        2018  West Virginia        74        839           4876
# 125        2018    Western Ky.        82        862           5059
# 126        2018  Western Mich.        57        813           5026
# 127        2018      Wisconsin        29        814           4474
# 128        2018        Wyoming        19        818           3914
#
#            Yards_Play_Allowed  Off_TDs_Allowed  Total_TDs_Allowed  \
# Unique_ID
# 0                        5.06               11                 12
# ...

# %%
offense_firstdowns = final_df[['Year','Team','Unique_ID',
 'First_Down_Rank',
 'First_Down_Runs',
 'First_Down_Passes',
 'First_Down_Penalties',
 'First_Downs']]
offense_firstdowns.set_index("Unique_ID", inplace=True)
offense_firstdowns
# Out:
#            Year           Team  First_Down_Rank  First_Down_Runs  \
# Unique_ID
# 0          2020      Air Force               14               52
# 1          2020          Akron               24               68
# 2          2020        Alabama               92               76
# 3          2020      App State              101              105
# 4          2020        Arizona               16               55
# ...         ...            ...              ...              ...
# 124        2018  West Virginia               73              112
# 125        2018    Western Ky.               72              112
# 126        2018  Western Mich.               58              112
# 127        2018      Wisconsin               19               98
# 128        2018        Wyoming               16               96
#
#            First_Down_Passes  First_Down_Penalties  First_Downs
# Unique_ID
# 0                         46                     8          106
# ...

# %%
defense_firstdowns = final_df[['Year','Team','Unique_ID',
 'Opp_First_Down_Runs',
 'Opp_First_Down_Passes',
 'Opp_First_Down_Penalties',
 'Opp_First_Downs']]
defense_firstdowns.set_index("Unique_ID", inplace=True)
defense_firstdowns
# Out:
#            Year           Team  Opp_First_Down_Runs  Opp_First_Down_Passes  \
# Unique_ID
# 0          2020      Air Force                   52                     46
# 1          2020          Akron                   68                     49
# 2          2020        Alabama                   76                    119
# 3          2020      App State                  105                     95
# 4          2020        Arizona                   55                     43
# ...         ...            ...                  ...                    ...
# 124        2018  West Virginia                  112                    131
# 125        2018    Western Ky.                  112                    127
# 126        2018  Western Mich.                  112                    123
# 127        2018      Wisconsin                   98                    108
# 128        2018        Wyoming                   96                    111
#
#            Opp_First_Down_Penalties  Opp_First_Downs
# ...

# %%
offense_fourthdowns = final_df[['Year','Team','Unique_ID',
 'X4th_Down_Rank',
 'X4th_Attempts',
 'X4th_Conversions',
 'X4th_Percent']]
offense_fourthdowns.set_index("Unique_ID", inplace=True)
offense_fourthdowns
# Out:
#            Year           Team  X4th_Down_Rank  X4th_Attempts  \
# Unique_ID
# 0          2020      Air Force              14              8
# 1          2020          Akron              98              4
# 2          2020        Alabama             102              3
# 3          2020      App State              61             11
# 4          2020        Arizona             122              3
# ...         ...            ...             ...            ...
# 124        2018  West Virginia              49              9
# 125        2018    Western Ky.             115              9
# 126        2018  Western Mich.              40             20
# 127        2018      Wisconsin             109              5
# 128        2018        Wyoming             123              4
#
#            X4th_Conversions  X4th_Percent
# Unique_ID
# 0                        11         0.727
# 1                         9         0.444
# 2                         7         0.429
# ...

# %%
defense_fourthdowns = final_df[['Year','Team','Unique_ID',
 'Opp_4th_Conversion',
 'Opp_4th_Attempt',
 'Opponent_4th_Percent'
]]
defense_fourthdowns.set_index("Unique_ID", inplace=True)
defense_fourthdowns
# Out:
#            Year           Team  Opp_4th_Conversion  Opp_4th_Attempt  \
# Unique_ID
# 0          2020      Air Force                   3               10
# 1          2020          Akron                   4                7
# 2          2020        Alabama                  11               19
# 3          2020      App State                  13               27
# 4          2020        Arizona                   5                8
# ...         ...            ...                 ...              ...
# 124        2018  West Virginia                  12               19
# 125        2018    Western Ky.                  12               22
# 126        2018  Western Mich.                   8               16
# 127        2018      Wisconsin                   7               13
# 128        2018        Wyoming                  11               16
#
#            Opponent_4th_Percent
# Unique_ID
# 0                         0.300
# 1                         0.571
# ...

# %%
offense_kickoffs = final_df[['Year','Team','Unique_ID',
 'Kickoffs_Returned',
 'Kickoff_Return_Yards',
 'Kickoff_Return_Touchdowns',
 'Avg_Yard_per_Kickoff_Return']]
offense_kickoffs.set_index("Unique_ID", inplace=True)
offense_kickoffs
# Out:
#            Year           Team  Kickoffs_Returned  Kickoff_Return_Yards  \
# Unique_ID
# 0          2020      Air Force                 14                     9
# 1          2020          Akron                 16                     6
# 2          2020        Alabama                 33                    17
# 3          2020      App State                 42                    17
# 4          2020        Arizona                  2                    17
# ...         ...            ...                ...                   ...
# 124        2018  West Virginia                 44                    25
# 125        2018    Western Ky.                 35                    13
# 126        2018  Western Mich.                 57                     6
# 127        2018      Wisconsin                 13                    54
# 128        2018        Wyoming                 22                    30
#
#            Kickoff_Return_Touchdowns  Avg_Yard_per_Kickoff_Return
# Unique_ID
# ...

# %%
defense_kickoffs = final_df[['Year','Team','Unique_ID',
 'Opp_Kickoff_Returns',
 'Kickoff_Touchbacks',
 'Opponent_Kickoff_Return_Yards',
 'Opp_Kickoff_Return_Touchdowns_Allowed',
 'Avg_Yards_per_Kickoff_Return_Allowed']]
defense_kickoffs.set_index("Unique_ID", inplace=True)
defense_kickoffs
# Out:
#            Year           Team  Opp_Kickoff_Returns  Kickoff_Touchbacks  \
# Unique_ID
# 0          2020      Air Force                   14                   9
# 1          2020          Akron                   16                   6
# 2          2020        Alabama                   33                  17
# 3          2020      App State                   42                  17
# 4          2020        Arizona                    2                  17
# ...         ...            ...                  ...                 ...
# 124        2018  West Virginia                   44                  25
# 125        2018    Western Ky.                   35                  13
# 126        2018  Western Mich.                   57                   6
# 127        2018      Wisconsin                   13                  54
# 128        2018        Wyoming                   22                  30
#
#            Opponent_Kickoff_Return_Yards  \
# Unique_ID
# ...

# %%
offense_passing = final_df[['Year','Team','Unique_ID',
 'Passing_Off_Rank',
 'Pass_Attempts',
 'Pass_Completions',
 'Interceptions_Thrown_x',
 'Pass_Yards',
 'Pass_Yards_Attempt',
 'Yards_Completion',
 'Pass_Touchdowns',
 'Pass_Yards_Per_Game']]
offense_passing.set_index("Unique_ID", inplace=True)
offense_passing
# Out:
#            Year           Team  Passing_Off_Rank  Pass_Attempts  \
# Unique_ID
# 0          2020      Air Force               126             61
# 1          2020          Akron               119            148
# 2          2020        Alabama                 5            350
# 3          2020      App State               105            300
# 4          2020        Arizona                77            189
# ...         ...            ...               ...            ...
# 124        2018  West Virginia                 4            445
# 125        2018    Western Ky.                69            431
# 126        2018  Western Mich.                62            396
# 127        2018      Wisconsin               118            304
# 128        2018        Wyoming               124            276
#
#            Pass_Completions  Interceptions_Thrown_x  Pass_Yards  \
# Unique_ID
# 0                        34                       3         502
# ...

# %%
defense_passing = final_df[['Year','Team','Unique_ID',
 'Opp_Completions_Allowed',
 'Opp_Pass_Attempts',
 'Opp_Pass_Yds_Allowed',
 'Opp_Pass_TDs_Allowed',
 'Yards_Attempt_Allowed',
 'Yards_Completion_Allowed',
 'Pass_Yards_Per_Game_Allowed']]
defense_passing.set_index("Unique_ID", inplace=True)
defense_passing
# Out:
#            Year           Team  Opp_Completions_Allowed  Opp_Pass_Attempts  \
# Unique_ID
# 0          2020      Air Force                       88                143
# 1          2020          Akron                       85                127
# 2          2020        Alabama                      227                393
# 3          2020      App State                      168                350
# 4          2020        Arizona                       80                122
# ...         ...            ...                      ...                ...
# 124        2018  West Virginia                      247                389
# 125        2018    Western Ky.                      228                406
# 126        2018  Western Mich.                      205                328
# 127        2018      Wisconsin                      209                360
# 128        2018        Wyoming                      241                394
#
# ...

# %%
penalties = final_df[['Year','Team','Unique_ID',
 'Penalty_Rank',
 'Penalties',
 'Penalty_Yards',
 'Penalty_Yards_Per_Game']]
penalties.set_index("Unique_ID", inplace=True)
penalties
# Out:
#            Year           Team  Penalty_Rank  Penalties  Penalty_Yards  \
# Unique_ID
# 0          2020      Air Force            19         27            245
# 1          2020          Akron             2         24            190
# 2          2020        Alabama            46         66            522
# 3          2020      App State           107         88            811
# 4          2020        Arizona            89         34            294
# ...         ...            ...           ...        ...            ...
# 124        2018  West Virginia           106         85            800
# 125        2018    Western Ky.            77         79            683
# 126        2018  Western Mich.            59         77            678
# 127        2018      Wisconsin            56         74            657
# 128        2018        Wyoming            51         72            596
#
#            Penalty_Yards_Per_Game
# Unique_ID
# 0                           40.83
# ...

# %%
offense_punts = final_df[['Year','Team','Unique_ID',
 'Punt_Return_Rank',
 'Punt_Returns',
 'Net_Punt_Return_Yards',
 'Punt_Return_Touchdowns',
 'Avg_Yards_Per_Punt_Return',
]]
offense_punts.set_index("Unique_ID", inplace=True)
offense_punts
# Out:
#            Year           Team  Punt_Return_Rank  Punt_Returns  \
# Unique_ID
# 0          2020      Air Force                26             4
# 1          2020          Akron                67            20
# 2          2020        Alabama                32             4
# 3          2020      App State                14            18
# 4          2020        Arizona                92             6
# ...         ...            ...               ...           ...
# 124        2018  West Virginia                56             9
# 125        2018    Western Ky.                99             7
# 126        2018  Western Mich.                58            13
# 127        2018      Wisconsin               109            17
# 128        2018        Wyoming                44            21
#
#            Net_Punt_Return_Yards  Punt_Return_Touchdowns  \
# Unique_ID
# 0                             15                       0
# 1                            144                       0
# ...

# %%
defense_punts = final_df[['Year','Team','Unique_ID',
 'Punt_Return_Def_Rank',
 'Opp_Punt_Returns',
 'Opp_Net_Punt_Return_Yards',
 'Opp_Punt_Return_Touchdowns_Allowed',
 'Avg_Yards_Allowed_per_Punt_Return'
]]
defense_punts.set_index("Unique_ID", inplace=True)
defense_punts
# Out:
#            Year           Team  Punt_Return_Def_Rank  Opp_Punt_Returns  \
# Unique_ID
# 0          2020      Air Force                    26                 4
# 1          2020          Akron                    67                20
# 2          2020        Alabama                    32                 4
# 3          2020      App State                    14                18
# 4          2020        Arizona                    92                 6
# ...         ...            ...                   ...               ...
# 124        2018  West Virginia                    56                 9
# 125        2018    Western Ky.                    99                 7
# 126        2018  Western Mich.                    58                13
# 127        2018      Wisconsin                   109                17
# 128        2018        Wyoming                    44                21
#
#            Opp_Net_Punt_Return_Yards  Opp_Punt_Return_Touchdowns_Allowed  \
# Unique_ID
# ...

# %%
offense_redzone = final_df[['Year','Team','Unique_ID',
 'Redzone_Off_Rank',
 'Redzone_Attempts',
 'Redzone_Rush_TD',
 'Redzone_Pass_TD',
 'Redzone_Field_Goals_Made',
 'Redzone_Scores',
 'Redzone_Points']]
offense_redzone.set_index("Unique_ID", inplace=True)
offense_redzone
# Out:
#            Year           Team  Redzone_Off_Rank  Redzone_Attempts  \
# Unique_ID
# 0          2020      Air Force               117                24
# 1          2020          Akron                41                14
# 2          2020        Alabama                11                60
# 3          2020      App State               106                52
# 4          2020        Arizona               119                13
# ...         ...            ...               ...               ...
# 124        2018  West Virginia                89                53
# 125        2018    Western Ky.               119                42
# 126        2018  Western Mich.                83                55
# 127        2018      Wisconsin                41                53
# 128        2018        Wyoming                87                27
#
#            Redzone_Rush_TD  Redzone_Pass_TD  Redzone_Field_Goals_Made  \
# Unique_ID
# ...

# %%
defense_redzone = final_df[['Year','Team','Unique_ID',
 'Redzone_Def_Rank',
 'Opp_Redzone_Attempts',
 'Opp_Redzone_Rush_TD_Allowed',
 'Opp_Redzone_Pass_Touchdowns_Allowed',
 'Opp_Redzone_Field_Goals_Made',
 'Opp_Redzone_Scores',
 'Redzone_Points_Allowed'
]]
defense_redzone.set_index("Unique_ID", inplace=True)
defense_redzone
# Out:
#            Year           Team  Redzone_Def_Rank  Opp_Redzone_Attempts  \
# Unique_ID
# 0          2020      Air Force                 5                    13
# 1          2020          Akron                33                    27
# 2          2020        Alabama                28                    30
# 3          2020      App State                24                    37
# 4          2020        Arizona               104                    28
# ...         ...            ...               ...                   ...
# 124        2018  West Virginia                93                    45
# 125        2018    Western Ky.                51                    49
# 126        2018  Western Mich.               117                    55
# 127        2018      Wisconsin                77                    44
# 128        2018        Wyoming                91                    36
#
#            Opp_Redzone_Rush_TD_Allowed  Opp_Redzone_Pass_Touchdowns_Allowed  \
# Unique_ID
# ...

# %%
offense_rushing = final_df[['Year','Team','Unique_ID',
 'Rushing_Off_Rank',
 'Rush_Attempts',
 'Rush_Yds',
 'Yards_Rush',
 'Rushing_TD',
 'Rushing_Yards_per_Game']]
offense_rushing.set_index("Unique_ID", inplace=True)
offense_rushing
# Out:
#            Year           Team  Rushing_Off_Rank  Rush_Attempts  Rush_Yds  \
# Unique_ID
# 0          2020      Air Force                 1            312      1834
# 1          2020          Akron                86            212       849
# 2          2020        Alabama                44            414      2088
# 3          2020      App State                 7            545      3179
# 4          2020        Arizona                73            184       782
# ...         ...            ...               ...            ...       ...
# 124        2018  West Virginia                75            425      1931
# 125        2018    Western Ky.               103            439      1642
# 126        2018  Western Mich.                38            566      2593
# 127        2018      Wisconsin                 6            571      3554
# 128        2018        Wyoming                39            495      2393
#
#            Yards_Rush  Rushing_TD  Rushing_Yards_per_Game
# ...

# %%
defense_rushing = final_df[['Year','Team','Unique_ID',
 'Rushing_Def_Rank',
 'Opp_Rush_Attempts',
 'Opp_Rush_Yards_Alloweed',
 'Yds_Rush_Allowed',
 'Opp_Rush_Touchdowns_Allowed',
 'Rush_Yards_Per_Game_Allowed']]
defense_rushing.set_index("Unique_ID", inplace=True)
defense_rushing
# Out:
#            Year           Team  Rushing_Def_Rank  Opp_Rush_Attempts  \
# Unique_ID
# 0          2020      Air Force                33                217
# 1          2020          Akron               120                238
# 2          2020        Alabama                12                374
# 3          2020      App State                49                448
# 4          2020        Arizona               125                229
# ...         ...            ...               ...                ...
# 124        2018  West Virginia                48                450
# 125        2018    Western Ky.                77                456
# 126        2018  Western Mich.                68                485
# 127        2018      Wisconsin                54                454
# 128        2018        Wyoming                25                424
#
#            Opp_Rush_Yards_Alloweed  Yds_Rush_Allowed  \
# Unique_ID
# 0                              819              3.77
# ...

# %%
sacks = final_df[['Year','Team','Unique_ID',
 'Sack_Rank',
 'Sacks',
 'Sack_Yards',
 'Average_Sacks_per_Game']]
sacks.set_index("Unique_ID", inplace=True)
sacks
# Out:
#            Year           Team  Sack_Rank  Sacks  Sack_Yards  \
# Unique_ID
# 0          2020      Air Force          3      2          19
# 1          2020          Akron        125     26         162
# 2          2020        Alabama         25     16         101
# 3          2020      App State         40     21         131
# 4          2020        Arizona        120     18         118
# ...         ...            ...        ...    ...         ...
# 124        2018  West Virginia         82     29         204
# 125        2018    Western Ky.         97     32         204
# 126        2018  Western Mich.         27     20         103
# 127        2018      Wisconsin         43     24         151
# 128        2018        Wyoming         53     24         204
#
#            Average_Sacks_per_Game
# Unique_ID
# 0                            0.33
# 1                            4.33
# 2                            1.45
# 3                            1.75
# ...

# %%
turnovers = final_df[['Year','Team','Unique_ID',
 'Turnover_Rank',
 'Fumbles_Recovered',
 'Opponents_Intercepted',
 'Turnovers_Gain',
 'Fumbles_Lost',
 'Interceptions_Thrown_y',
 'Turnovers_Lost',
 'Turnover_Margin',
 'Avg_Turnover_Margin_per_Game']]
turnovers.set_index("Unique_ID", inplace=True)
turnovers
# Out:
#            Year           Team  Turnover_Rank  Fumbles_Recovered  \
# Unique_ID
# 0          2020      Air Force             58                  3
# 1          2020          Akron             98                  4
# 2          2020        Alabama             12                 10
# 3          2020      App State             57                  3
# 4          2020        Arizona            126                  1
# ...         ...            ...            ...                ...
# 124        2018  West Virginia             23                  9
# 125        2018    Western Ky.             52                  6
# 126        2018  Western Mich.             63                 11
# 127        2018      Wisconsin             63                 11
# 128        2018        Wyoming             40                  5
#
#            Opponents_Intercepted  Turnovers_Gain  Fumbles_Lost  \
# Unique_ID
# 0                              5               8             5
# ...

# %%
rds_connection_string = "postgres:@localhost:5432/college_football"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# []

# %%
win_loss.to_sql(name='win_loss', con=engine, if_exists='append', index=False)

# %%
offense.to_sql(name='offense', con=engine, if_exists='append', index=False)

# %%
defense.to_sql(name='defense', con=engine, if_exists='append', index=False)

# %%
offense_firstdowns.to_sql(name='offense_firstdowns', con=engine, if_exists='append', index=False)

# %%
defense_firstdowns.to_sql(name='defense_firstdowns', con=engine, if_exists='append', index=False)

# %%
offense_fourthdowns.to_sql(name='offense_fourthdowns', con=engine, if_exists='append', index=False)

# %%
defense_fourthdowns.to_sql(name='defense_fourthdowns', con=engine, if_exists='append', index=False)

# %%
offense_kickoffs.to_sql(name='offense_kickoffs', con=engine, if_exists='append', index=False)

# %%
defense_kickoffs.to_sql(name='defense_kickoffs', con=engine, if_exists='append', index=False)

# %%
offense_passing.to_sql(name='offense_passing', con=engine, if_exists='append', index=False)

# %%
defense_passing.to_sql(name='defense_passing', con=engine, if_exists='append', index=False)

# %%
penalties.to_sql(name='penalties', con=engine, if_exists='append', index=False)

# %%
offense_punts.to_sql(name='offense_punts', con=engine, if_exists='append', index=False)

# %%
defense_punts.to_sql(name='defense_punts', con=engine, if_exists='append', index=False)

# %%
offense_redzone.to_sql(name='offense_redzone', con=engine, if_exists='append', index=False)

# %%
defense_redzone.to_sql(name='defense_redzone', con=engine, if_exists='append', index=False)

# %%
offense_rushing.to_sql(name='offense_rushing', con=engine, if_exists='append', index=False)

# %%
defense_rushing.to_sql(name='defense_rushing', con=engine, if_exists='append', index=False)

# %%
sacks.to_sql(name='sacks', con=engine, if_exists='append', index=False)

# %%
turnovers.to_sql(name='turnovers', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['offense_passing',
#  'defense_passing',
#  'penalties',
#  'offense_punts',
#  'defense_punts',
#  'offense_redzone',
#  'defense_redzone',
#  'offense_rushing',
#  'defense_rushing',
#  'sacks',
#  'turnovers',
#  'win_loss',
#  'offense',
#  'defense',
#  'offense_firstdowns',
#  'defense_firstdowns',
#  'offense_fourthdowns',
#  'defense_fourthdowns',
#  'offense_kickoffs',
#  'defense_kickoffs']

# %%
pd.read_sql_query('select * from turnovers', con=engine)
# Out:
#      Year           Team  Turnover_Rank  Fumbles_Recovered  \
# 0    2020      Air Force             58                  3
# 1    2020          Akron             98                  4
# 2    2020        Alabama             12                 10
# 3    2020      App State             57                  3
# 4    2020        Arizona            126                  1
# ..    ...            ...            ...                ...
# 381  2018  West Virginia             23                  9
# 382  2018    Western Ky.             52                  6
# 383  2018  Western Mich.             63                 11
# 384  2018      Wisconsin             63                 11
# 385  2018        Wyoming             40                  5
#
#      Opponents_Intercepted  Turnovers_Gain  Fumbles_Lost  \
# 0                        5               8             5
# 1                        2               6             3
# 2                       11              21             7
# ...

# %% [markdown]
# # PHASE TWO

# %%
csv_file3 = "Resources/stadium.csv"
stadium_df = pd.read_csv(csv_file3)
stadium_df.head()
# Out:
#    Stadium Code                            Name        City State  Capacity  \
# 0             1             Jordan-Hare Stadium      Auburn    AL     87451
# 1             2                    Legion Field  Birmingham    AL     71594
# 2             3            Ladd-Peebles Stadium      Mobile    AL     40646
# 3             4  Movie Gallery Veterans Stadium        Troy    AL     30000
# 4             5            Bryant-Denny Stadium  Tuscaloosa    AL     92138
#
#      Surface  Year Opened
# 0      Grass         1939
# 1      Grass         1927
# 2  FieldTurf         1948
# 3  AstroPlay         1950
# 4      Grass         1929

# %%
csv_file3 = "Resources/team.csv"
team_df = pd.read_csv(csv_file3)
team_df.head()
# Out:
#    Team Code           Name  Conference Code
# 0          5          Akron              875
# 1          8        Alabama              911
# 2          9            UAB            24312
# 3         28  Arizona State              905
# 4         29        Arizona              905

# %%
csv_file3 = "Resources/game.csv"
game_df = pd.read_csv(csv_file3)
game_df.head()
# Out:
#          Game Code        Date  Visit Team Code  Home Team Code  Stadium Code  \
# 0    5012820130829  08/29/2013                5             128           146
# 1  102063020130829  08/29/2013              102             630            18
# 2  299004720130829  08/29/2013              299              47            48
# 3  305030620130829  08/29/2013              305             306            47
# 4  314071820130829  08/29/2013              314             718            58
#
#    Site
# 0  TEAM
# 1  TEAM
# 2  TEAM
# 3  TEAM
# 4  TEAM

# %%
team_cols = ["Team Code", "Name"]
team_transformed= team_df[team_cols].copy()

team_transformed = team_transformed.rename(columns={"Team Code": "team_id",
                                                          "Name": "team_name"})

team_transformed.drop_duplicates("team_id", inplace=True)
team_transformed.set_index("team_id", inplace=True)

team_transformed.head()
# Out:
#              team_name
# team_id
# 5                Akron
# 8              Alabama
# 9                  UAB
# 28       Arizona State
# 29             Arizona

# %%
stadium_cols = ["Stadium Code", "Name", "Capacity", 'City']
staium_transformed = stadium_df[stadium_cols].copy()


staium_transformed = staium_transformed.rename(columns={"Stadium Code": "stadium_id",
                                                         "Name": "stadium_name",
                                                         "Capacity": "capacity",
                                                         "City": "city"})

staium_transformed.set_index("stadium_id", inplace=True)

staium_transformed.head()
# Out:
#                               stadium_name  capacity        city
# stadium_id
# 1                      Jordan-Hare Stadium     87451      Auburn
# 2                             Legion Field     71594  Birmingham
# 3                     Ladd-Peebles Stadium     40646      Mobile
# 4           Movie Gallery Veterans Stadium     30000        Troy
# 5                     Bryant-Denny Stadium     92138  Tuscaloosa

# %%
game_cols = ["Visit Team Code", "Home Team Code", "Stadium Code"]
game_transformed = game_df[game_cols].copy()

game_transformed = game_transformed.rename(columns={"Visit Team Code": "visit_id",
                                                         "Home Team Code": "stadium_name",
                                                         "Stadium Code": "capacity",
                                                         "City": "city"})

game_transformed.set_index("stadium_id", inplace=True)

game_transformed.head()
